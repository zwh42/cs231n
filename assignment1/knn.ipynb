# %% [markdown]
# # k-Nearest Neighbor (kNN) exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# The kNN classifier consists of two stages:
#
# - During training, the classifier takes the training data and simply remembers it
# - During testing, kNN classifies every test image by comparing to all training images and transfering the labels of the k most similar training examples
# - The value of k is cross-validated
#
# In this exercise you will implement these steps and understand the basic Image Classification pipeline, cross-validation, and gain proficiency in writing efficient, vectorized code.

# %%
# Run some setup code for this notebook.

import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# This is a bit of magic to make matplotlib figures appear inline in the notebook
# rather than in a new window.
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
# Load the raw CIFAR-10 data.
cifar10_dir = '/Users/zhaowenhao/MachineLearning/cs231n_2017/cifar-10-batches-py'
X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

# As a sanity check, we print out the size of the training and test data.
print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Training data shape:  (50000, 32, 32, 3)
# Training labels shape:  (50000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %%
# Visualize some examples from the dataset.
# We show a few examples of training images from each class.
classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
num_classes = len(classes)
samples_per_class = 7
for y, cls in enumerate(classes):
    idxs = np.flatnonzero(y_train == y)
    print(idxs)
    idxs = np.random.choice(idxs, samples_per_class, replace=False)
    for i, idx in enumerate(idxs):
        plt_idx = i * num_classes + y + 1
        plt.subplot(samples_per_class, num_classes, plt_idx)
        plt.imshow(X_train[idx].astype('uint8'))
        plt.axis('off')
        if i == 0:
            plt.title(cls)
plt.show()
# Out:
# [   29    30    35 ..., 49941 49992 49994]
# [    4     5    32 ..., 49993 49998 49999]
# [    6    13    18 ..., 49987 49991 49995]
# [    9    17    21 ..., 49979 49982 49983]
# [    3    10    20 ..., 49981 49984 49990]
# [   27    40    51 ..., 49964 49980 49988]
# [    0    19    22 ..., 49962 49966 49996]
# [    7    11    12 ..., 49965 49978 49986]
# [    8    62    69 ..., 49968 49976 49985]
# [    1     2    14 ..., 49963 49971 49997]

# %%
# Subsample the data for more efficient code execution in this exercise
num_training = 5000
mask = list(range(num_training))
X_train = X_train[mask]
y_train = y_train[mask]

print(X_train.shape)

num_test = 500
mask = list(range(num_test))
X_test = X_test[mask]
y_test = y_test[mask]
# Out:
# (5000, 32, 32, 3)

# %%
# Reshape the image data into rows
X_train = np.reshape(X_train, (X_train.shape[0], -1))
X_test = np.reshape(X_test, (X_test.shape[0], -1))
print(X_train.shape, X_test.shape)
# Out:
# (5000, 3072) (500, 3072)

# %%
from cs231n.classifiers import KNearestNeighbor

# Create a kNN classifier instance. 
# Remember that training a kNN classifier is a noop: 
# the Classifier simply remembers the data and does no further processing 
classifier = KNearestNeighbor()
classifier.train(X_train, y_train)

# %% [markdown]
# We would now like to classify the test data with the kNN classifier. Recall that we can break down this process into two steps:
#
# 1. First we must compute the distances between all test examples and all train examples.
# 2. Given these distances, for each test example we find the k nearest examples and have them vote for the label
#
# Lets begin with computing the distance matrix between all training and test examples. For example, if there are **Ntr** training examples and **Nte** test examples, this stage should result in a **Nte x Ntr** matrix where each element (i,j) is the distance between the i-th test and j-th train example.
#
# First, open `cs231n/classifiers/k_nearest_neighbor.py` and implement the function `compute_distances_two_loops` that uses a (very inefficient) double loop over all pairs of (test, train) examples and computes the distance matrix one element at a time.

# %%
# Open cs231n/classifiers/k_nearest_neighbor.py and implement
# compute_distances_two_loops.

# Test your implementation:
dists = classifier.compute_distances_two_loops(X_test)
print(dists.shape)
# Out:
# (500, 5000)

# %%
# We can visualize the distance matrix: each row is a single test example and
# its distances to training examples
plt.imshow(dists, interpolation='none')
plt.show()

# %% [markdown]
# **Inline Question #1:** Notice the structured patterns in the distance matrix, where some rows or columns are visible brighter. (Note that with the default color scheme black indicates low distances while white indicates high distances.)
#
# - What in the data is the cause behind the distinctly bright rows?
# - What causes the columns?

# %% [markdown]
# **Your Answer**: *fill this in.*

# %%
# Now implement the function predict_labels and run the code below:
# We use k = 1 (which is Nearest Neighbor).
y_test_pred = classifier.predict_labels(dists, k=1)

# Compute and print the fraction of correctly predicted examples
num_correct = np.sum(y_test_pred == y_test)
accuracy = float(num_correct) / num_test
print('Got %d / %d correct => accuracy: %f' % (num_correct, num_test, accuracy))
# Out:
# nearest index for  0 : [420]
# y label [4]
# 4.0
# nearest index for  1 : [2192]
# y label [9]
# 9.0
# nearest index for  2 : [4469]
# y label [8]
# 8.0
# nearest index for  3 : [252]
# y label [8]
# 8.0
# nearest index for  4 : [1881]
# y label [4]
# 4.0
# nearest index for  5 : [2654]
# y label [4]
# 4.0
# nearest index for  6 : [4033]
# y label [3]
# 3.0
# nearest index for  7 : [910]
# y label [2]
# 2.0
# nearest index for  8 : [4808]
# y label [5]
# 5.0
# nearest index for  9 : [2096]
# y label [8]
# 8.0
# nearest index for  10 : [303]
# y label [2]
# 2.0
# nearest index for  11 : [139]
# y label [8]
# 8.0
# nearest index for  12 : [2745]
# y label [5]
# 5.0
# nearest index for  13 : [825]
# y label [7]
# 7.0
# nearest index for  14 : [271]
# y label [2]
# 2.0
# nearest index for  15 : [4183]
# y label [2]
# 2.0
# nearest index for  16 : [4153]
# y label [5]
# 5.0
# nearest index for  17 : [80]
# y label [3]
# 3.0
# nearest index for  18 : [3059]
# y label [1]
# 1.0
# nearest index for  19 : [1881]
# y label [4]
# 4.0
# nearest index for  20 : [2693]
# y label [2]
# 2.0
# nearest index for  21 : [1522]
# y label [0]
# 0.0
# nearest index for  22 : [4282]
# y label [0]
# 0.0
# nearest index for  23 : [313]
# y label [6]
# 6.0
# nearest index for  24 : [2764]
# y label [2]
# 2.0
# nearest index for  25 : [420]
# y label [4]
# 4.0
# nearest index for  26 : [1359]
# y label [2]
# 2.0
# nearest index for  27 : [2074]
# y label [7]
# 7.0
# nearest index for  28 : [2678]
# y label [2]
# 2.0
# nearest index for  29 : [3712]
# y label [6]
# 6.0
# nearest index for  30 : [2124]
# y label [6]
# 6.0
# nearest index for  31 : [2133]
# y label [2]
# 2.0
# nearest index for  32 : [398]
# y label [4]
# 4.0
# nearest index for  33 : [1176]
# y label [6]
# 6.0
# nearest index for  34 : [4066]
# y label [8]
# 8.0
# nearest index for  35 : [3649]
# y label [7]
# 7.0
# nearest index for  36 : [2133]
# y label [2]
# 2.0
# nearest index for  37 : [2172]
# y label [8]
# 8.0
# nearest index for  38 : [982]
# y label [4]
# 4.0
# nearest index for  39 : [2567]
# y label [2]
# 2.0
# nearest index for  40 : [3579]
# y label [8]
# 8.0
# nearest index for  41 : [1596]
# y label [6]
# 6.0
# nearest index for  42 : [2966]
# y label [2]
# 2.0
# nearest index for  43 : [2943]
# y label [4]
# 4.0
# nearest index for  44 : [763]
# y label [9]
# 9.0
# nearest index for  45 : [1759]
# y label [0]
# 0.0
# nearest index for  46 : [1355]
# y label [5]
# 5.0
# nearest index for  47 : [564]
# y label [0]
# 0.0
# nearest index for  48 : [3718]
# y label [4]
# 4.0
# nearest index for  49 : [2812]
# y label [2]
# 2.0
# nearest index for  50 : [4134]
# y label [7]
# 7.0
# nearest index for  51 : [1092]
# y label [8]
# 8.0
# nearest index for  52 : [3]
# y label [4]
# 4.0
# nearest index for  53 : [3178]
# y label [3]
# 3.0
# nearest index for  54 : [2344]
# y label [8]
# 8.0
# nearest index for  55 : [1229]
# y label [8]
# 8.0
# nearest index for  56 : [3031]
# y label [5]
# 5.0
# nearest index for  57 : [3136]
# y label [0]
# 0.0
# nearest index for  58 : [1759]
# y label [0]
# 0.0
# nearest index for  59 : [254]
# y label [4]
# 4.0
# nearest index for  60 : [254]
# y label [4]
# 4.0
# nearest index for  61 : [1537]
# y label [6]
# 6.0
# nearest index for  62 : [2112]
# y label [6]
# 6.0
# nearest index for  63 : [4128]
# y label [3]
# 3.0
# nearest index for  64 : [4007]
# y label [3]
# 3.0
# nearest index for  65 : [910]
# y label [2]
# 2.0
# nearest index for  66 : [716]
# y label [8]
# 8.0
# nearest index for  67 : [786]
# y label [8]
# 8.0
# nearest index for  68 : [1345]
# y label [3]
# 3.0
# nearest index for  69 : [749]
# y label [9]
# 9.0
# nearest index for  70 : [2543]
# y label [2]
# 2.0
# nearest index for  71 : [1695]
# y label [4]
# 4.0
# nearest index for  72 : [3579]
# y label [8]
# 8.0
# nearest index for  73 : [1039]
# y label [0]
# 0.0
# nearest index for  74 : [4053]
# y label [4]
# 4.0
# nearest index for  75 : [3418]
# y label [4]
# 4.0
# nearest index for  76 : [1360]
# y label [6]
# 6.0
# nearest index for  77 : [4310]
# y label [3]
# 3.0
# nearest index for  78 : [4907]
# y label [6]
# 6.0
# nearest index for  79 : [3503]
# y label [8]
# 8.0
# nearest index for  80 : [3638]
# y label [8]
# 8.0
# nearest index for  81 : [850]
# y label [3]
# 3.0
# nearest index for  82 : [3949]
# y label [5]
# 5.0
# nearest index for  83 : [2341]
# y label [0]
# 0.0
# nearest index for  84 : [1118]
# y label [7]
# 7.0
# nearest index for  85 : [3116]
# y label [4]
# 4.0
# nearest index for  86 : [4827]
# y label [3]
# 3.0
# nearest index for  87 : [2172]
# y label [8]
# 8.0
# nearest index for  88 : [2172]
# y label [8]
# 8.0
# nearest index for  89 : [1229]
# y label [8]
# 8.0
# nearest index for  90 : [1759]
# y label [0]
# 0.0
# nearest index for  91 : [979]
# y label [4]
# 4.0
# nearest index for  92 : [2172]
# y label [8]
# 8.0
# nearest index for  93 : [4172]
# y label [1]
# 1.0
# nearest index for  94 : [10]
# y label [4]
# 4.0
# nearest index for  95 : [1759]
# y label [0]
# 0.0
# nearest index for  96 : [347]
# y label [6]
# 6.0
# nearest index for  97 : [1759]
# y label [0]
# 0.0
# nearest index for  98 : [3842]
# y label [0]
# 0.0
# nearest index for  99 : [1770]
# y label [8]
# 8.0
# nearest index for  100 : [3408]
# y label [4]
# 4.0
# nearest index for  101 : [662]
# y label [7]
# 7.0
# nearest index for  102 : [3048]
# y label [6]
# 6.0
# nearest index for  103 : [4195]
# y label [4]
# 4.0
# nearest index for  104 : [1559]
# y label [1]
# 1.0
# nearest index for  105 : [3452]
# y label [1]
# 1.0
# nearest index for  106 : [1881]
# y label [4]
# 4.0
# nearest index for  107 : [4907]
# y label [6]
# 6.0
# nearest index for  108 : [4808]
# y label [5]
# 5.0
# nearest index for  109 : [2108]
# y label [5]
# 5.0
# nearest index for  110 : [3855]
# y label [4]
# 4.0
# nearest index for  111 : [373]
# y label [0]
# 0.0
# nearest index for  112 : [4954]
# y label [3]
# 3.0
# nearest index for  113 : [2859]
# y label [0]
# 0.0
# nearest index for  114 : [982]
# y label [4]
# 4.0
# nearest index for  115 : [4987]
# y label [4]
# 4.0
# nearest index for  116 : [2867]
# y label [2]
# 2.0
# nearest index for  117 : [271]
# y label [2]
# 2.0
# nearest index for  118 : [4741]
# y label [4]
# 4.0
# nearest index for  119 : [692]
# y label [6]
# 6.0
# nearest index for  120 : [2172]
# y label [8]
# 8.0
# nearest index for  121 : [959]
# y label [4]
# 4.0
# nearest index for  122 : [420]
# y label [4]
# 4.0
# nearest index for  123 : [2583]
# y label [6]
# 6.0
# nearest index for  124 : [1770]
# y label [8]
# 8.0
# nearest index for  125 : [2133]
# y label [2]
# 2.0
# nearest index for  126 : [1759]
# y label [0]
# 0.0
# nearest index for  127 : [4755]
# y label [2]
# 2.0
# nearest index for  128 : [4590]
# y label [6]
# 6.0
# nearest index for  129 : [2993]
# y label [2]
# 2.0
# nearest index for  130 : [403]
# y label [2]
# 2.0
# nearest index for  131 : [2362]
# y label [1]
# 1.0
# nearest index for  132 : [3246]
# y label [0]
# 0.0
# nearest index for  133 : [1690]
# y label [6]
# 6.0
# nearest index for  134 : [3411]
# y label [6]
# 6.0
# nearest index for  135 : [767]
# y label [5]
# 5.0
# nearest index for  136 : [4164]
# y label [9]
# 9.0
# nearest index for  137 : [974]
# y label [0]
# 0.0
# nearest index for  138 : [3558]
# y label [2]
# 2.0
# nearest index for  139 : [4320]
# y label [8]
# 8.0
# nearest index for  140 : [3164]
# y label [2]
# 2.0
# nearest index for  141 : [4453]
# y label [2]
# 2.0
# nearest index for  142 : [1017]
# y label [6]
# 6.0
# nearest index for  143 : [4956]
# y label [5]
# 5.0
# nearest index for  144 : [562]
# y label [8]
# 8.0
# nearest index for  145 : [4985]
# y label [4]
# 4.0
# nearest index for  146 : [4426]
# y label [2]
# 2.0
# nearest index for  147 : [4463]
# y label [5]
# 5.0
# nearest index for  148 : [157]
# y label [5]
# 5.0
# nearest index for  149 : [4283]
# y label [8]
# 8.0
# nearest index for  150 : [600]
# y label [0]
# 0.0
# nearest index for  151 : [101]
# y label [3]
# 3.0
# nearest index for  152 : [710]
# y label [6]
# 6.0
# nearest index for  153 : [341]
# y label [0]
# 0.0
# nearest index for  154 : [3670]
# y label [8]
# 8.0
# nearest index for  155 : [1324]
# y label [4]
# 4.0
# nearest index for  156 : [2441]
# y label [8]
# 8.0
# nearest index for  157 : [4834]
# y label [8]
# 8.0
# nearest index for  158 : [2266]
# y label [5]
# 5.0
# nearest index for  159 : [4527]
# y label [4]
# 4.0
# nearest index for  160 : [348]
# y label [0]
# 0.0
# nearest index for  161 : [3189]
# y label [4]
# 4.0
# nearest index for  162 : [3403]
# y label [6]
# 6.0
# nearest index for  163 : [3393]
# y label [4]
# 4.0
# nearest index for  164 : [2881]
# y label [8]
# 8.0
# nearest index for  165 : [4018]
# y label [0]
# 0.0
# nearest index for  166 : [2172]
# y label [8]
# 8.0
# nearest index for  167 : [4550]
# y label [6]
# 6.0
# nearest index for  168 : [2017]
# y label [5]
# 5.0
# nearest index for  169 : [3063]
# y label [0]
# 0.0
# nearest index for  170 : [3039]
# y label [8]
# 8.0
# nearest index for  171 : [898]
# y label [7]
# 7.0
# nearest index for  172 : [592]
# y label [8]
# 8.0
# nearest index for  173 : [3065]
# y label [8]
# 8.0
# nearest index for  174 : [1826]
# y label [4]
# 4.0
# nearest index for  175 : [1640]
# y label [4]
# 4.0
# nearest index for  176 : [3549]
# y label [0]
# 0.0
# nearest index for  177 : [951]
# y label [4]
# 4.0
# nearest index for  178 : [420]
# y label [4]
# 4.0
# nearest index for  179 : [554]
# y label [8]
# 8.0
# nearest index for  180 : [596]
# y label [8]
# 8.0
# nearest index for  181 : [695]
# y label [0]
# 0.0
# nearest index for  182 : [4211]
# y label [2]
# 2.0
# nearest index for  183 : [420]
# y label [4]
# 4.0
# nearest index for  184 : [695]
# y label [0]
# 0.0
# nearest index for  185 : [974]
# y label [0]
# 0.0
# nearest index for  186 : [2112]
# y label [6]
# 6.0
# nearest index for  187 : [4346]
# y label [3]
# 3.0
# nearest index for  188 : [3482]
# y label [8]
# 8.0
# nearest index for  189 : [4277]
# y label [8]
# 8.0
# nearest index for  190 : [2723]
# y label [3]
# 3.0
# nearest index for  191 : [3587]
# y label [4]
# 4.0
# nearest index for  192 : [1788]
# y label [2]
# 2.0
# nearest index for  193 : [2535]
# y label [2]
# 2.0
# nearest index for  194 : [951]
# y label [4]
# 4.0
# nearest index for  195 : [2116]
# y label [4]
# 4.0
# nearest index for  196 : [2979]
# y label [8]
# 8.0
# nearest index for  197 : [2176]
# y label [8]
# 8.0
# nearest index for  198 : [4184]
# y label [4]
# 4.0
# nearest index for  199 : [2567]
# y label [2]
# 2.0
# nearest index for  200 : [18]
# y label [2]
# 2.0
# nearest index for  201 : [4053]
# y label [4]
# 4.0
# nearest index for  202 : [554]
# y label [8]
# 8.0
# nearest index for  203 : [910]
# y label [2]
# 2.0
# nearest index for  204 : [2725]
# y label [4]
# 4.0
# nearest index for  205 : [403]
# y label [2]
# 2.0
# nearest index for  206 : [2350]
# y label [0]
# 0.0
# nearest index for  207 : [933]
# y label [2]
# 2.0
# nearest index for  208 : [1220]
# y label [6]
# 6.0
# nearest index for  209 : [2171]
# y label [0]
# 0.0
# nearest index for  210 : [1563]
# y label [6]
# 6.0
# nearest index for  211 : [121]
# y label [2]
# 2.0
# nearest index for  212 : [3436]
# y label [2]
# 2.0
# nearest index for  213 : [558]
# y label [2]
# 2.0
# nearest index for  214 : [2979]
# y label [8]
# 8.0
# nearest index for  215 : [2349]
# y label [2]
# 2.0
# nearest index for  216 : [1593]
# y label [0]
# 0.0
# nearest index for  217 : [3677]
# y label [9]
# 9.0
# nearest index for  218 : [4645]
# y label [0]
# 0.0
# nearest index for  219 : [3418]
# y label [4]
# 4.0
# nearest index for  220 : [4706]
# y label [7]
# 7.0
# nearest index for  221 : [336]
# y label [4]
# 4.0
# nearest index for  222 : [3623]
# y label [7]
# 7.0
# nearest index for  223 : [2350]
# y label [0]
# 0.0
# nearest index for  224 : [4288]
# y label [3]
# 3.0
# nearest index for  225 : [1809]
# y label [6]
# 6.0
# nearest index for  226 : [558]
# y label [2]
# 2.0
# nearest index for  227 : [2543]
# y label [2]
# 2.0
# nearest index for  228 : [2858]
# y label [4]
# 4.0
# nearest index for  229 : [4987]
# y label [4]
# 4.0
# nearest index for  230 : [4108]
# y label [3]
# 3.0
# nearest index for  231 : [3735]
# y label [1]
# 1.0
# nearest index for  232 : [963]
# y label [2]
# 2.0
# nearest index for  233 : [4108]
# y label [3]
# 3.0
# nearest index for  234 : [2172]
# y label [8]
# 8.0
# nearest index for  235 : [2247]
# y label [2]
# 2.0
# nearest index for  236 : [10]
# y label [4]
# 4.0
# nearest index for  237 : [3882]
# y label [9]
# 9.0
# nearest index for  238 : [1618]
# y label [5]
# 5.0
# nearest index for  239 : [2509]
# y label [5]
# 5.0
# nearest index for  240 : [77]
# y label [0]
# 0.0
# nearest index for  241 : [1284]
# y label [4]
# 4.0
# nearest index for  242 : [3116]
# y label [4]
# 4.0
# nearest index for  243 : [4477]
# y label [0]
# 0.0
# nearest index for  244 : [2247]
# y label [2]
# 2.0
# nearest index for  245 : [1122]
# y label [2]
# 2.0
# nearest index for  246 : [2605]
# y label [6]
# 6.0
# nearest index for  247 : [4477]
# y label [0]
# 0.0
# nearest index for  248 : [1832]
# y label [4]
# 4.0
# nearest index for  249 : [2507]
# y label [2]
# 2.0
# nearest index for  250 : [3376]
# y label [3]
# 3.0
# nearest index for  251 : [914]
# y label [6]
# 6.0
# nearest index for  252 : [299]
# y label [4]
# 4.0
# nearest index for  253 : [1530]
# y label [2]
# 2.0
# nearest index for  254 : [2831]
# y label [6]
# 6.0
# nearest index for  255 : [982]
# y label [4]
# 4.0
# nearest index for  256 : [1881]
# y label [4]
# 4.0
# nearest index for  257 : [2003]
# y label [8]
# 8.0
# nearest index for  258 : [2003]
# y label [8]
# 8.0
# nearest index for  259 : [4801]
# y label [4]
# 4.0
# nearest index for  260 : [2745]
# y label [5]
# 5.0
# nearest index for  261 : [2839]
# y label [4]
# 4.0
# nearest index for  262 : [4106]
# y label [4]
# 4.0
# nearest index for  263 : [4493]
# y label [2]
# 2.0
# nearest index for  264 : [2213]
# y label [4]
# 4.0
# nearest index for  265 : [2096]
# y label [8]
# 8.0
# nearest index for  266 : [2212]
# y label [8]
# 8.0
# nearest index for  267 : [4297]
# y label [4]
# 4.0
# nearest index for  268 : [3627]
# y label [7]
# 7.0
# nearest index for  269 : [1787]
# y label [2]
# 2.0
# nearest index for  270 : [383]
# y label [2]
# 2.0
# nearest index for  271 : [1283]
# y label [2]
# 2.0
# nearest index for  272 : [2150]
# y label [6]
# 6.0
# nearest index for  273 : [3787]
# y label [3]
# 3.0
# nearest index for  274 : [3144]
# y label [8]
# 8.0
# nearest index for  275 : [1027]
# y label [6]
# 6.0
# nearest index for  276 : [4571]
# y label [0]
# 0.0
# nearest index for  277 : [1746]
# y label [4]
# 4.0
# nearest index for  278 : [337]
# y label [5]
# 5.0
# nearest index for  279 : [2684]
# y label [6]
# 6.0
# nearest index for  280 : [3623]
# y label [7]
# 7.0
# nearest index for  281 : [887]
# y label [4]
# 4.0
# nearest index for  282 : [2796]
# y label [6]
# 6.0
# nearest index for  283 : [105]
# y label [1]
# 1.0
# nearest index for  284 : [811]
# y label [8]
# 8.0
# nearest index for  285 : [1826]
# y label [4]
# 4.0
# nearest index for  286 : [359]
# y label [5]
# 5.0
# nearest index for  287 : [4540]
# y label [0]
# 0.0
# nearest index for  288 : [69]
# y label [8]
# 8.0
# nearest index for  289 : [4594]
# y label [8]
# 8.0
# nearest index for  290 : [1141]
# y label [8]
# 8.0
# nearest index for  291 : [3847]
# y label [2]
# 2.0
# nearest index for  292 : [1838]
# y label [2]
# 2.0
# nearest index for  293 : [2894]
# y label [2]
# 2.0
# nearest index for  294 : [1161]
# y label [6]
# 6.0
# nearest index for  295 : [2573]
# y label [4]
# 4.0
# nearest index for  296 : [3166]
# y label [4]
# 4.0
# nearest index for  297 : [1178]
# y label [0]
# 0.0
# nearest index for  298 : [2229]
# y label [8]
# 8.0
# nearest index for  299 : [420]
# y label [4]
# 4.0
# nearest index for  300 : [3383]
# y label [4]
# 4.0
# nearest index for  301 : [3608]
# y label [2]
# 2.0
# nearest index for  302 : [337]
# y label [5]
# 5.0
# nearest index for  303 : [986]
# y label [2]
# 2.0
# nearest index for  304 : [1677]
# y label [2]
# 2.0
# nearest index for  305 : [2172]
# y label [8]
# 8.0
# nearest index for  306 : [1643]
# y label [8]
# 8.0
# nearest index for  307 : [982]
# y label [4]
# 4.0
# nearest index for  308 : [1933]
# y label [6]
# 6.0
# nearest index for  309 : [1838]
# y label [2]
# 2.0
# nearest index for  310 : [1323]
# y label [8]
# 8.0
# nearest index for  311 : [2730]
# y label [5]
# 5.0
# nearest index for  312 : [974]
# y label [0]
# 0.0
# nearest index for  313 : [4645]
# y label [0]
# 0.0
# nearest index for  314 : [2982]
# y label [3]
# 3.0
# nearest index for  315 : [2017]
# y label [5]
# 5.0
# nearest index for  316 : [4755]
# y label [2]
# 2.0
# nearest index for  317 : [254]
# y label [4]
# 4.0
# nearest index for  318 : [4108]
# y label [3]
# 3.0
# nearest index for  319 : [420]
# y label [4]
# 4.0
# nearest index for  320 : [4808]
# y label [5]
# 5.0
# nearest index for  321 : [1271]
# y label [3]
# 3.0
# nearest index for  322 : [2112]
# y label [6]
# 6.0
# nearest index for  323 : [931]
# y label [6]
# 6.0
# nearest index for  324 : [1016]
# y label [6]
# 6.0
# nearest index for  325 : [2894]
# y label [2]
# 2.0
# nearest index for  326 : [420]
# y label [4]
# 4.0
# nearest index for  327 : [2266]
# y label [5]
# 5.0
# nearest index for  328 : [3948]
# y label [4]
# 4.0
# nearest index for  329 : [3077]
# y label [4]
# 4.0
# nearest index for  330 : [4200]
# y label [1]
# 1.0
# nearest index for  331 : [2953]
# y label [9]
# 9.0
# nearest index for  332 : [3164]
# y label [2]
# 2.0
# nearest index for  333 : [4687]
# y label [4]
# 4.0
# nearest index for  334 : [2573]
# y label [4]
# 4.0
# nearest index for  335 : [4583]
# y label [2]
# 2.0
# nearest index for  336 : [3873]
# y label [6]
# 6.0
# nearest index for  337 : [1797]
# y label [8]
# 8.0
# nearest index for  338 : [4056]
# y label [2]
# 2.0
# nearest index for  339 : [4208]
# y label [6]
# 6.0
# nearest index for  340 : [2106]
# y label [4]
# 4.0
# nearest index for  341 : [985]
# y label [6]
# 6.0
# nearest index for  342 : [2034]
# y label [0]
# 0.0
# nearest index for  343 : [4808]
# y label [5]
# 5.0
# nearest index for  344 : [4577]
# y label [0]
# 0.0
# nearest index for  345 : [180]
# y label [4]
# 4.0
# nearest index for  346 : [1221]
# y label [4]
# 4.0
# nearest index for  347 : [804]
# y label [2]
# 2.0
# nearest index for  348 : [1993]
# y label [5]
# 5.0
# nearest index for  349 : [1284]
# y label [4]
# 4.0
# nearest index for  350 : [4618]
# y label [9]
# 9.0
# nearest index for  351 : [2595]
# y label [2]
# 2.0
# nearest index for  352 : [2166]
# y label [8]
# 8.0
# nearest index for  353 : [1965]
# y label [3]
# 3.0
# nearest index for  354 : [933]
# y label [2]
# 2.0
# nearest index for  355 : [767]
# y label [5]
# 5.0
# nearest index for  356 : [2796]
# y label [6]
# 6.0
# nearest index for  357 : [951]
# y label [4]
# 4.0
# nearest index for  358 : [1092]
# y label [8]
# 8.0
# nearest index for  359 : [1413]
# y label [1]
# 1.0
# nearest index for  360 : [196]
# y label [2]
# 2.0
# nearest index for  361 : [2859]
# y label [0]
# 0.0
# nearest index for  362 : [971]
# y label [8]
# 8.0
# nearest index for  363 : [733]
# y label [0]
# 0.0
# nearest index for  364 : [4592]
# y label [0]
# 0.0
# nearest index for  365 : [1770]
# y label [8]
# 8.0
# nearest index for  366 : [2520]
# y label [4]
# 4.0
# nearest index for  367 : [3987]
# y label [0]
# 0.0
# nearest index for  368 : [4919]
# y label [0]
# 0.0
# nearest index for  369 : [4153]
# y label [5]
# 5.0
# nearest index for  370 : [2796]
# y label [6]
# 6.0
# nearest index for  371 : [2833]
# y label [2]
# 2.0
# nearest index for  372 : [2995]
# y label [4]
# 4.0
# nearest index for  373 : [909]
# y label [8]
# 8.0
# nearest index for  374 : [2253]
# y label [4]
# 4.0
# nearest index for  375 : [1273]
# y label [7]
# 7.0
# nearest index for  376 : [4828]
# y label [8]
# 8.0
# nearest index for  377 : [1092]
# y label [8]
# 8.0
# nearest index for  378 : [420]
# y label [4]
# 4.0
# nearest index for  379 : [3193]
# y label [2]
# 2.0
# nearest index for  380 : [420]
# y label [4]
# 4.0
# nearest index for  381 : [139]
# y label [8]
# 8.0
# nearest index for  382 : [317]
# y label [0]
# 0.0
# nearest index for  383 : [974]
# y label [0]
# 0.0
# nearest index for  384 : [3178]
# y label [3]
# 3.0
# nearest index for  385 : [4645]
# y label [0]
# 0.0
# nearest index for  386 : [1092]
# y label [8]
# 8.0
# nearest index for  387 : [2712]
# y label [4]
# 4.0
# nearest index for  388 : [2993]
# y label [2]
# 2.0
# nearest index for  389 : [2276]
# y label [6]
# 6.0
# nearest index for  390 : [906]
# y label [0]
# 0.0
# nearest index for  391 : [3259]
# y label [2]
# 2.0
# nearest index for  392 : [3418]
# y label [4]
# 4.0
# nearest index for  393 : [1842]
# y label [6]
# 6.0
# nearest index for  394 : [4007]
# y label [3]
# 3.0
# nearest index for  395 : [2465]
# y label [4]
# 4.0
# nearest index for  396 : [420]
# y label [4]
# 4.0
# nearest index for  397 : [1220]
# y label [6]
# 6.0
# nearest index for  398 : [4774]
# y label [0]
# 0.0
# nearest index for  399 : [4221]
# y label [3]
# 3.0
# nearest index for  400 : [4858]
# y label [1]
# 1.0
# nearest index for  401 : [1282]
# y label [8]
# 8.0
# nearest index for  402 : [4750]
# y label [4]
# 4.0
# nearest index for  403 : [566]
# y label [8]
# 8.0
# nearest index for  404 : [4053]
# y label [4]
# 4.0
# nearest index for  405 : [10]
# y label [4]
# 4.0
# nearest index for  406 : [1533]
# y label [2]
# 2.0
# nearest index for  407 : [1264]
# y label [4]
# 4.0
# nearest index for  408 : [4540]
# y label [0]
# 0.0
# nearest index for  409 : [3328]
# y label [3]
# 3.0
# nearest index for  410 : [1284]
# y label [4]
# 4.0
# nearest index for  411 : [1278]
# y label [0]
# 0.0
# nearest index for  412 : [2540]
# y label [2]
# 2.0
# nearest index for  413 : [1746]
# y label [4]
# 4.0
# nearest index for  414 : [2224]
# y label [2]
# 2.0
# nearest index for  415 : [1277]
# y label [9]
# 9.0
# nearest index for  416 : [695]
# y label [0]
# 0.0
# nearest index for  417 : [4393]
# y label [7]
# 7.0
# nearest index for  418 : [1881]
# y label [4]
# 4.0
# nearest index for  419 : [3784]
# y label [4]
# 4.0
# nearest index for  420 : [781]
# y label [6]
# 6.0
# nearest index for  421 : [3408]
# y label [4]
# 4.0
# nearest index for  422 : [982]
# y label [4]
# 4.0
# nearest index for  423 : [4087]
# y label [3]
# 3.0
# nearest index for  424 : [933]
# y label [2]
# 2.0
# nearest index for  425 : [2003]
# y label [8]
# 8.0
# nearest index for  426 : [1842]
# y label [6]
# 6.0
# nearest index for  427 : [3377]
# y label [4]
# 4.0
# nearest index for  428 : [4491]
# y label [2]
# 2.0
# nearest index for  429 : [3892]
# y label [6]
# 6.0
# nearest index for  430 : [1867]
# y label [2]
# 2.0
# nearest index for  431 : [3493]
# y label [8]
# 8.0
# nearest index for  432 : [3873]
# y label [6]
# 6.0
# nearest index for  433 : [4770]
# y label [6]
# 6.0
# nearest index for  434 : [1092]
# y label [8]
# 8.0
# nearest index for  435 : [2943]
# y label [4]
# 4.0
# nearest index for  436 : [882]
# y label [3]
# 3.0
# nearest index for  437 : [2842]
# y label [4]
# 4.0
# nearest index for  438 : [1530]
# y label [2]
# 2.0
# nearest index for  439 : [4661]
# y label [1]
# 1.0
# nearest index for  440 : [592]
# y label [8]
# 8.0
# nearest index for  441 : [10]
# y label [4]
# 4.0
# nearest index for  442 : [1557]
# y label [4]
# 4.0
# nearest index for  443 : [1711]
# y label [0]
# 0.0
# nearest index for  444 : [3587]
# y label [4]
# 4.0
# nearest index for  445 : [673]
# y label [2]
# 2.0
# nearest index for  446 : [2859]
# y label [0]
# 0.0
# nearest index for  447 : [2460]
# y label [0]
# 0.0
# nearest index for  448 : [2543]
# y label [2]
# 2.0
# nearest index for  449 : [2867]
# y label [2]
# 2.0
# nearest index for  450 : [1563]
# y label [6]
# 6.0
# nearest index for  451 : [31]
# y label [9]
# 9.0
# nearest index for  452 : [3953]
# y label [7]
# 7.0
# nearest index for  453 : [1686]
# y label [8]
# 8.0
# nearest index for  454 : [3984]
# y label [1]
# 1.0
# nearest index for  455 : [2543]
# y label [2]
# 2.0
# nearest index for  456 : [2983]
# y label [2]
# 2.0
# nearest index for  457 : [2812]
# y label [2]
# 2.0
# nearest index for  458 : [243]
# y label [6]
# 6.0
# nearest index for  459 : [882]
# y label [3]
# 3.0
# nearest index for  460 : [521]
# y label [4]
# 4.0
# nearest index for  461 : [287]
# y label [3]
# 3.0
# nearest index for  462 : [1067]
# y label [2]
# 2.0
# nearest index for  463 : [4905]
# y label [4]
# 4.0
# nearest index for  464 : [2868]
# y label [2]
# 2.0
# nearest index for  465 : [2213]
# y label [4]
# 4.0
# nearest index for  466 : [158]
# y label [4]
# 4.0
# nearest index for  467 : [2868]
# y label [2]
# 2.0
# nearest index for  468 : [4294]
# y label [3]
# 3.0
# nearest index for  469 : [1926]
# y label [0]
# 0.0
# nearest index for  470 : [3480]
# y label [2]
# 2.0
# nearest index for  471 : [2553]
# y label [7]
# 7.0
# nearest index for  472 : [328]
# y label [8]
# 8.0
# nearest index for  473 : [2415]
# y label [4]
# 4.0
# nearest index for  474 : [4350]
# y label [3]
# 3.0
# nearest index for  475 : [2922]
# y label [4]
# 4.0
# nearest index for  476 : [4224]
# y label [4]
# 4.0
# nearest index for  477 : [983]
# y label [0]
# 0.0
# nearest index for  478 : [4703]
# y label [2]
# 2.0
# nearest index for  479 : [558]
# y label [2]
# 2.0
# nearest index for  480 : [901]
# y label [8]
# 8.0
# nearest index for  481 : [3193]
# y label [2]
# 2.0
# nearest index for  482 : [2859]
# y label [0]
# 0.0
# nearest index for  483 : [2943]
# y label [4]
# 4.0
# nearest index for  484 : [820]
# y label [2]
# 2.0
# nearest index for  485 : [3874]
# y label [8]
# 8.0
# nearest index for  486 : [1185]
# y label [0]
# 0.0
# nearest index for  487 : [420]
# y label [4]
# 4.0
# nearest index for  488 : [974]
# y label [0]
# 0.0
# nearest index for  489 : [557]
# y label [0]
# 0.0
# nearest index for  490 : [3469]
# y label [8]
# 8.0
# nearest index for  491 : [749]
# y label [9]
# 9.0
# nearest index for  492 : [1431]
# y label [8]
# 8.0
# nearest index for  493 : [2830]
# y label [4]
# 4.0
# nearest index for  494 : [4758]
# y label [8]
# 8.0
# nearest index for  495 : [1853]
# y label [8]
# 8.0
# nearest index for  496 : [4283]
# y label [8]
# 8.0
# nearest index for  497 : [4398]
# y label [2]
# 2.0
# nearest index for  498 : [4224]
# y label [4]
# 4.0
# nearest index for  499 : [3979]
# y label [0]
# 0.0
# Got 137 / 500 correct => accuracy: 0.274000

# %% [markdown]
# You should expect to see approximately `27%` accuracy. Now lets try out a larger `k`, say `k = 5`:

# %%
y_test_pred = classifier.predict_labels(dists, k=5)
num_correct = np.sum(y_test_pred == y_test)
accuracy = float(num_correct) / num_test
print('Got %d / %d correct => accuracy: %f' % (num_correct, num_test, accuracy))
# Out:
# nearest index for  0 : [ 420 3684 4224 1161 4550]
# y label [4, 4, 4, 6, 6]
# 4.0
# nearest index for  1 : [2192 4848 2166 2172 3644]
# y label [9, 8, 8, 8, 0]
# 8.0
# nearest index for  2 : [4469  909 3904 1726  139]
# y label [8, 8, 8, 5, 8]
# 8.0
# nearest index for  3 : [ 252 4453 4270 2172 3039]
# y label [8, 2, 0, 8, 8]
# 8.0
# nearest index for  4 : [1881 3949 3797 4604 4262]
# y label [4, 5, 4, 2, 4]
# 4.0
# nearest index for  5 : [2654  347 1983 2372 4130]
# y label [4, 6, 5, 2, 6]
# 6.0
# nearest index for  6 : [4033  831   22 3525 1184]
# y label [3, 4, 6, 6, 2]
# 6.0
# nearest index for  7 : [ 910 4055 1838 2746  347]
# y label [2, 4, 2, 7, 6]
# 2.0
# nearest index for  8 : [4808 1686 1283 4634 4306]
# y label [5, 8, 2, 2, 2]
# 2.0
# nearest index for  9 : [2096 4320  126  193 1462]
# y label [8, 8, 1, 8, 9]
# 8.0
# nearest index for  10 : [ 303  456 1759 4808 1540]
# y label [2, 8, 0, 5, 0]
# 0.0
# nearest index for  11 : [ 139  722 2905 4291 4207]
# y label [8, 7, 4, 9, 8]
# 8.0
# nearest index for  12 : [2745 3540 4124  528  894]
# y label [5, 4, 3, 4, 5]
# 4.0
# nearest index for  13 : [ 825 4279  920  359 3122]
# y label [7, 6, 6, 5, 6]
# 6.0
# nearest index for  14 : [ 271 4066 2749 1264  420]
# y label [2, 8, 8, 4, 4]
# 4.0
# nearest index for  15 : [4183 4453 1832 3121 2749]
# y label [2, 2, 4, 8, 8]
# 2.0
# nearest index for  16 : [4153 1160 2550 4808 1600]
# y label [5, 3, 2, 5, 5]
# 5.0
# nearest index for  17 : [  80 4864 4045  254  383]
# y label [3, 4, 8, 4, 2]
# 4.0
# nearest index for  18 : [3059 2192 2670 3115 2166]
# y label [1, 9, 8, 8, 8]
# 8.0
# nearest index for  19 : [1881 4139 4604 4112 2535]
# y label [4, 3, 2, 7, 2]
# 2.0
# nearest index for  20 : [2693 1440 1038 3116 4703]
# y label [2, 2, 6, 4, 2]
# 2.0
# nearest index for  21 : [1522 3382 3842 2446  650]
# y label [0, 0, 0, 0, 0]
# 0.0
# nearest index for  22 : [4282 2277 2660  906 2350]
# y label [0, 0, 0, 0, 0]
# 0.0
# nearest index for  23 : [ 313 2196 2069 2812 4703]
# y label [6, 4, 4, 2, 2]
# 2.0
# nearest index for  24 : [2764 2859  982 1065 4998]
# y label [2, 0, 4, 2, 4]
# 2.0
# nearest index for  25 : [ 420 4224 3913 1728 4583]
# y label [4, 4, 4, 4, 2]
# 4.0
# nearest index for  26 : [1359 1126 1318 1491  673]
# y label [2, 6, 6, 4, 2]
# 2.0
# nearest index for  27 : [2074  711 3845 2905  898]
# y label [7, 4, 2, 4, 7]
# 4.0
# nearest index for  28 : [2678  571 2481 3061  254]
# y label [2, 6, 7, 9, 4]
# 2.0
# nearest index for  29 : [3712 1692 3178 2812 1530]
# y label [6, 4, 3, 2, 2]
# 2.0
# nearest index for  30 : [2124 1530 1596  626 4509]
# y label [6, 2, 6, 0, 0]
# 0.0
# nearest index for  31 : [2133   42 1143 3608 4703]
# y label [2, 2, 4, 2, 2]
# 2.0
# nearest index for  32 : [ 398 2522  130 4905 1677]
# y label [4, 5, 4, 4, 2]
# 4.0
# nearest index for  33 : [1176  721 1962 3748 4449]
# y label [6, 6, 3, 5, 3]
# 3.0
# nearest index for  34 : [4066 3874  749 2820 2966]
# y label [8, 8, 9, 8, 2]
# 8.0
# nearest index for  35 : [3649 4565 1881 2873 3590]
# y label [7, 1, 4, 8, 6]
# 1.0
# nearest index for  36 : [2133 4208 3116 3164 2573]
# y label [2, 6, 4, 2, 4]
# 2.0
# nearest index for  37 : [2172 4540 3638 1709 3478]
# y label [8, 0, 8, 0, 0]
# 0.0
# nearest index for  38 : [ 982 1458 1360 3608 3638]
# y label [4, 2, 6, 2, 8]
# 2.0
# nearest index for  39 : [2567  993 1314 3408 3336]
# y label [2, 5, 8, 4, 0]
# 0.0
# nearest index for  40 : [3579 1404 4723 4502 4634]
# y label [8, 8, 8, 8, 2]
# 8.0
# nearest index for  41 : [1596  850 2124 1530 3588]
# y label [6, 3, 6, 2, 6]
# 6.0
# nearest index for  42 : [2966 3768 4066  626 4715]
# y label [2, 7, 8, 0, 4]
# 0.0
# nearest index for  43 : [2943 3670  552 1491 3217]
# y label [4, 8, 6, 4, 4]
# 4.0
# nearest index for  44 : [ 763  365 1999  983 2155]
# y label [9, 8, 0, 0, 4]
# 0.0
# nearest index for  45 : [1759 4540 1065 3745 2979]
# y label [0, 0, 2, 8, 8]
# 0.0
# nearest index for  46 : [1355 3935 2266 3173 3043]
# y label [5, 1, 5, 5, 3]
# 5.0
# nearest index for  47 : [ 564 1162  906 3065 2610]
# y label [0, 8, 0, 8, 2]
# 0.0
# nearest index for  48 : [3718 1746 3797 4262  622]
# y label [4, 4, 4, 4, 4]
# 4.0
# nearest index for  49 : [2812 4732 2983 2725  622]
# y label [2, 2, 2, 4, 4]
# 2.0
# nearest index for  50 : [4134 3640 1711  135 2664]
# y label [7, 8, 0, 8, 9]
# 8.0
# nearest index for  51 : [1092  906 3065  420 1141]
# y label [8, 0, 8, 4, 8]
# 8.0
# nearest index for  52 : [   3  961 3170  132 3540]
# y label [4, 6, 8, 6, 4]
# 4.0
# nearest index for  53 : [3178 2966 4135 2372 2725]
# y label [3, 2, 5, 2, 4]
# 2.0
# nearest index for  54 : [2344 2003 1711 3904 4226]
# y label [8, 8, 0, 8, 8]
# 8.0
# nearest index for  55 : [1229 4298 1284 1323 2962]
# y label [8, 8, 4, 8, 0]
# 8.0
# nearest index for  56 : [3031 3408 4905 4153 1600]
# y label [5, 4, 4, 5, 5]
# 5.0
# nearest index for  57 : [3136 2602 3467 2134  850]
# y label [0, 6, 1, 6, 3]
# 6.0
# nearest index for  58 : [1759 1065 3627 4683 2859]
# y label [0, 2, 7, 0, 0]
# 0.0
# nearest index for  59 : [ 254  658 4398  349 2476]
# y label [4, 0, 2, 0, 2]
# 0.0
# nearest index for  60 : [ 254 1027  933 3326   42]
# y label [4, 6, 2, 4, 2]
# 2.0
# nearest index for  61 : [1537 1716  217  243  692]
# y label [6, 7, 5, 6, 6]
# 6.0
# nearest index for  62 : [2112  682 4284 4279 4126]
# y label [6, 6, 6, 6, 6]
# 6.0
# nearest index for  63 : [4128 4053 1726 3998 1185]
# y label [3, 4, 5, 8, 0]
# 0.0
# nearest index for  64 : [4007 2695 4715 4224 1500]
# y label [3, 4, 4, 4, 2]
# 4.0
# nearest index for  65 : [ 910  180 1207   10 3528]
# y label [2, 4, 2, 4, 6]
# 2.0
# nearest index for  66 : [ 716 1404 1284 1973 4868]
# y label [8, 8, 4, 1, 0]
# 8.0
# nearest index for  67 : [ 786 3254 3918 2034 1620]
# y label [8, 2, 0, 0, 2]
# 0.0
# nearest index for  68 : [1345 3178  838 1530 2616]
# y label [3, 3, 6, 2, 7]
# 3.0
# nearest index for  69 : [ 749 4684 4775  139 1726]
# y label [9, 9, 1, 8, 5]
# 9.0
# nearest index for  70 : [2543 4683 1065  557 2867]
# y label [2, 0, 2, 0, 2]
# 2.0
# nearest index for  71 : [1695 1917  347 4510 2812]
# y label [4, 6, 6, 7, 2]
# 6.0
# nearest index for  72 : [3579 4540 4807 1686 1106]
# y label [8, 0, 8, 8, 8]
# 8.0
# nearest index for  73 : [1039 3121 1162 1092 4758]
# y label [0, 8, 8, 8, 8]
# 8.0
# nearest index for  74 : [4053 3304 4544  407 3882]
# y label [4, 0, 7, 0, 9]
# 0.0
# nearest index for  75 : [3418 2197  800  933 2415]
# y label [4, 3, 2, 2, 4]
# 2.0
# nearest index for  76 : [1360 4228 4527 1759 2540]
# y label [6, 2, 4, 0, 2]
# 2.0
# nearest index for  77 : [4310 2745 2181  197 4755]
# y label [3, 5, 3, 3, 2]
# 3.0
# nearest index for  78 : [4907 4324 2842 4103 4946]
# y label [6, 6, 4, 4, 6]
# 6.0
# nearest index for  79 : [3503 2176  782 1618 2464]
# y label [8, 8, 0, 5, 8]
# 8.0
# nearest index for  80 : [3638 2172 4540 4724 1119]
# y label [8, 8, 0, 8, 0]
# 8.0
# nearest index for  81 : [ 850 1367 1351 1982 3664]
# y label [3, 6, 3, 6, 4]
# 3.0
# nearest index for  82 : [3949 3841  420 4685  830]
# y label [5, 6, 4, 6, 2]
# 6.0
# nearest index for  83 : [2341 4056 2441 3669 3263]
# y label [0, 2, 8, 2, 0]
# 0.0
# nearest index for  84 : [1118 2346 4471 4056 3263]
# y label [7, 2, 2, 2, 0]
# 2.0
# nearest index for  85 : [3116 2840 4066  271  111]
# y label [4, 9, 8, 2, 8]
# 8.0
# nearest index for  86 : [4827 4034 1469   47 4577]
# y label [3, 2, 7, 2, 0]
# 2.0
# nearest index for  87 : [2172 2577  185 3449  676]
# y label [8, 8, 0, 8, 1]
# 8.0
# nearest index for  88 : [2172 1770 3304 3215  566]
# y label [8, 8, 0, 8, 8]
# 8.0
# nearest index for  89 : [1229 1431 1999   69 1166]
# y label [8, 8, 0, 8, 0]
# 8.0
# nearest index for  90 : [1759 4861 3034 1973 3157]
# y label [0, 0, 1, 1, 7]
# 0.0
# nearest index for  91 : [ 979 4550 1530 1838 2812]
# y label [4, 6, 2, 2, 2]
# 2.0
# nearest index for  92 : [2172 1278 3215 2462 2707]
# y label [8, 0, 8, 8, 0]
# 8.0
# nearest index for  93 : [4172 1458 1563 2989  909]
# y label [1, 2, 6, 6, 8]
# 6.0
# nearest index for  94 : [  10 2253 2725 3226 1798]
# y label [4, 4, 4, 2, 2]
# 4.0
# nearest index for  95 : [1759  933 2576  130 1677]
# y label [0, 2, 4, 4, 2]
# 2.0
# nearest index for  96 : [ 347  420 3684 1968 4429]
# y label [6, 4, 4, 4, 4]
# 4.0
# nearest index for  97 : [1759 2859  303  974 2534]
# y label [0, 0, 2, 0, 8]
# 0.0
# nearest index for  98 : [3842  266  317  108 3892]
# y label [0, 3, 0, 2, 6]
# 0.0
# nearest index for  99 : [1770 1882 2233  982 4082]
# y label [8, 4, 0, 4, 6]
# 4.0
# nearest index for  100 : [3408 2922 2301 4905 3377]
# y label [4, 4, 7, 4, 4]
# 4.0
# nearest index for  101 : [ 662 1221 2922  373 1366]
# y label [7, 4, 4, 0, 4]
# 4.0
# nearest index for  102 : [3048 1351 4087  918 1730]
# y label [6, 3, 3, 5, 6]
# 3.0
# nearest index for  103 : [4195 3654 4445 3749 3077]
# y label [4, 3, 7, 3, 4]
# 3.0
# nearest index for  104 : [1559 2922  250 4224  149]
# y label [1, 4, 1, 4, 4]
# 4.0
# nearest index for  105 : [3452  524 1597  676 1392]
# y label [1, 1, 8, 1, 8]
# 1.0
# nearest index for  106 : [1881 3528 1917 4421 3260]
# y label [4, 6, 6, 6, 4]
# 6.0
# nearest index for  107 : [4907 2650 4732 2124 3226]
# y label [6, 6, 2, 6, 2]
# 6.0
# nearest index for  108 : [4808 1091 1933 4923 1161]
# y label [5, 5, 6, 8, 6]
# 5.0
# nearest index for  109 : [2108 3303 4153 4881  157]
# y label [5, 8, 5, 6, 5]
# 5.0
# nearest index for  110 : [3855  804 2041 4349   58]
# y label [4, 2, 2, 3, 4]
# 2.0
# nearest index for  111 : [ 373 4190 4588 4353 1283]
# y label [0, 6, 2, 0, 2]
# 0.0
# nearest index for  112 : [4954 4752 1132 4208 4789]
# y label [3, 6, 6, 6, 6]
# 6.0
# nearest index for  113 : [2859 4224 1143 1759 3164]
# y label [0, 4, 4, 0, 2]
# 0.0
# nearest index for  114 : [ 982 1284  102 4254 4119]
# y label [4, 4, 9, 7, 7]
# 4.0
# nearest index for  115 : [4987 2678 1937 1101 3835]
# y label [4, 2, 4, 6, 7]
# 4.0
# nearest index for  116 : [2867 2066  153 4398  303]
# y label [2, 0, 4, 2, 2]
# 2.0
# nearest index for  117 : [ 271 4066 3919 2905  909]
# y label [2, 8, 4, 4, 8]
# 4.0
# nearest index for  118 : [4741 1843  781  918 1387]
# y label [4, 8, 6, 5, 4]
# 4.0
# nearest index for  119 : [ 692  521 3182   86 2990]
# y label [6, 4, 4, 4, 4]
# 4.0
# nearest index for  120 : [2172 3638 4540  199 4226]
# y label [8, 8, 0, 0, 8]
# 8.0
# nearest index for  121 : [ 959 3219 3897 4108 1122]
# y label [4, 4, 4, 3, 2]
# 4.0
# nearest index for  122 : [ 420 2812 4647  564  906]
# y label [4, 2, 2, 0, 0]
# 0.0
# nearest index for  123 : [2583 2982 4208 3608 3181]
# y label [6, 3, 6, 2, 2]
# 2.0
# nearest index for  124 : [1770  987  554 1665  600]
# y label [8, 8, 8, 8, 0]
# 8.0
# nearest index for  125 : [2133 4224  420 4429 3164]
# y label [2, 4, 4, 4, 2]
# 4.0
# nearest index for  126 : [1759 2310 3246  592 1643]
# y label [0, 6, 0, 8, 8]
# 0.0
# nearest index for  127 : [4755 2730  197 1842 1207]
# y label [2, 5, 3, 6, 2]
# 2.0
# nearest index for  128 : [4590 4801 3989 4773 4969]
# y label [6, 4, 7, 4, 4]
# 4.0
# nearest index for  129 : [2993  120  827 1065 1759]
# y label [2, 2, 2, 2, 0]
# 2.0
# nearest index for  130 : [ 403 2543 1283 4998  383]
# y label [2, 2, 2, 4, 2]
# 2.0
# nearest index for  131 : [2362 2768 3922 4540 2172]
# y label [1, 9, 1, 0, 8]
# 1.0
# nearest index for  132 : [3246 1708 4794  592 4277]
# y label [0, 0, 8, 8, 8]
# 8.0
# nearest index for  133 : [1690 4472 2017 4452 2084]
# y label [6, 3, 5, 6, 1]
# 6.0
# nearest index for  134 : [3411 2017  203  695  820]
# y label [6, 5, 3, 0, 2]
# 0.0
# nearest index for  135 : [ 767 3077 2093  557 2993]
# y label [5, 4, 2, 0, 2]
# 2.0
# nearest index for  136 : [4164 4128 4545 1711 4775]
# y label [9, 3, 9, 0, 1]
# 9.0
# nearest index for  137 : [ 974 3376 1759  982 1065]
# y label [0, 3, 0, 4, 2]
# 0.0
# nearest index for  138 : [3558  622 2983 1184 4732]
# y label [2, 4, 2, 2, 2]
# 2.0
# nearest index for  139 : [4320 3039  793 1229 3579]
# y label [8, 8, 8, 8, 8]
# 8.0
# nearest index for  140 : [3164  130 1759  933 4224]
# y label [2, 4, 0, 2, 4]
# 2.0
# nearest index for  141 : [4453 1759 3121 1873 4032]
# y label [2, 0, 8, 5, 4]
# 0.0
# nearest index for  142 : [1017 3985 3634 3892 4027]
# y label [6, 4, 8, 6, 0]
# 6.0
# nearest index for  143 : [4956  849  784 4583  986]
# y label [5, 2, 5, 2, 2]
# 2.0
# nearest index for  144 : [ 562 2272  252 1398 3995]
# y label [8, 8, 8, 8, 5]
# 8.0
# nearest index for  145 : [4985 4113 1139 1665 3438]
# y label [4, 2, 2, 8, 0]
# 2.0
# nearest index for  146 : [4426 1136 2112 1596 3843]
# y label [2, 5, 6, 6, 3]
# 6.0
# nearest index for  147 : [4463 3194 1600 4755  986]
# y label [5, 3, 5, 2, 2]
# 2.0
# nearest index for  148 : [ 157 1160  931  197 1600]
# y label [5, 3, 6, 3, 5]
# 3.0
# nearest index for  149 : [4283 1036 4166 4579 3152]
# y label [8, 8, 3, 5, 5]
# 5.0
# nearest index for  150 : [ 600 3246 2868 3617 1593]
# y label [0, 0, 2, 3, 0]
# 0.0
# nearest index for  151 : [ 101  338 2472 4164 1120]
# y label [3, 7, 7, 9, 3]
# 3.0
# nearest index for  152 : [ 710 2595 2782 1798 2350]
# y label [6, 2, 3, 2, 0]
# 2.0
# nearest index for  153 : [ 341  974 2193  987 1972]
# y label [0, 0, 2, 8, 9]
# 0.0
# nearest index for  154 : [3670 4773 1491 2943 4801]
# y label [8, 4, 4, 4, 4]
# 4.0
# nearest index for  155 : [1324 1881 2116 2130 2694]
# y label [4, 4, 4, 3, 6]
# 4.0
# nearest index for  156 : [2441  957 2034 1432 2617]
# y label [8, 2, 0, 0, 0]
# 0.0
# nearest index for  157 : [4834 2483  139  793 1711]
# y label [8, 8, 8, 8, 0]
# 8.0
# nearest index for  158 : [2266 3949 2400 3873 3684]
# y label [5, 5, 6, 6, 4]
# 5.0
# nearest index for  159 : [4527 1500 4868  592  716]
# y label [4, 2, 0, 8, 8]
# 8.0
# nearest index for  160 : [ 348 2017  820 2598  349]
# y label [0, 5, 2, 0, 0]
# 0.0
# nearest index for  161 : [3189 1299 2112 4213 2535]
# y label [4, 4, 6, 4, 2]
# 4.0
# nearest index for  162 : [3403 3080 1164 1542  773]
# y label [6, 5, 3, 2, 8]
# 2.0
# nearest index for  163 : [3393 2983 1838 1746  622]
# y label [4, 2, 2, 4, 4]
# 4.0
# nearest index for  164 : [2881  659 3438 2675 1278]
# y label [8, 9, 0, 0, 0]
# 0.0
# nearest index for  165 : [4018 4527  898 3878 3438]
# y label [0, 4, 7, 9, 0]
# 0.0
# nearest index for  166 : [2172 4540  566  252 3638]
# y label [8, 0, 8, 8, 8]
# 8.0
# nearest index for  167 : [4550 2372 2812 1838  347]
# y label [6, 2, 2, 2, 6]
# 2.0
# nearest index for  168 : [2017 4804  762 2893  820]
# y label [5, 8, 5, 6, 2]
# 5.0
# nearest index for  169 : [3063  749 4544  165 4053]
# y label [0, 9, 7, 0, 4]
# 0.0
# nearest index for  170 : [3039 3579 1439 4489 1106]
# y label [8, 8, 8, 9, 8]
# 8.0
# nearest index for  171 : [ 898 4427 4794 3573  982]
# y label [7, 7, 8, 7, 4]
# 7.0
# nearest index for  172 : [ 592 1759 2993 2213  383]
# y label [8, 0, 2, 4, 2]
# 2.0
# nearest index for  173 : [3065 1162 4925 2894 4758]
# y label [8, 8, 0, 2, 8]
# 8.0
# nearest index for  174 : [1826  887 4224 2966 1776]
# y label [4, 4, 4, 2, 7]
# 4.0
# nearest index for  175 : [1640 4557 4291 1195 2905]
# y label [4, 1, 9, 0, 4]
# 4.0
# nearest index for  176 : [3549 2777 3049 1713 2247]
# y label [0, 6, 0, 5, 2]
# 0.0
# nearest index for  177 : [ 951 4703  337 3403 2069]
# y label [4, 2, 5, 6, 4]
# 4.0
# nearest index for  178 : [ 420 3873 2595 4235 4868]
# y label [4, 6, 2, 6, 0]
# 6.0
# nearest index for  179 : [ 554 2882 4060 1139 4571]
# y label [8, 0, 0, 2, 0]
# 0.0
# nearest index for  180 : [ 596 2162  743 3860 1439]
# y label [8, 3, 1, 8, 8]
# 8.0
# nearest index for  181 : [ 695 3985 1158 3634 1722]
# y label [0, 4, 4, 8, 6]
# 4.0
# nearest index for  182 : [4211  933  990 2133 3506]
# y label [2, 2, 2, 2, 2]
# 2.0
# nearest index for  183 : [ 420 1500 4868 4224  564]
# y label [4, 2, 0, 4, 0]
# 0.0
# nearest index for  184 : [ 695 2794 3010 2977 3962]
# y label [0, 5, 6, 7, 0]
# 0.0
# nearest index for  185 : [ 974 1720 3157 1759 4453]
# y label [0, 8, 7, 0, 2]
# 0.0
# nearest index for  186 : [2112 2507 4217 1596 2124]
# y label [6, 2, 6, 6, 6]
# 6.0
# nearest index for  187 : [4346 2875 3739  571 2310]
# y label [3, 2, 6, 6, 6]
# 6.0
# nearest index for  188 : [3482  691 4322 3004 1028]
# y label [8, 3, 0, 6, 9]
# 0.0
# nearest index for  189 : [4277 1243 3745 1323 3829]
# y label [8, 0, 8, 8, 8]
# 8.0
# nearest index for  190 : [2723  144 3359 4954 2543]
# y label [3, 2, 8, 3, 2]
# 2.0
# nearest index for  191 : [3587  254 4808 3408 2426]
# y label [4, 4, 5, 4, 8]
# 4.0
# nearest index for  192 : [1788 1143 2133 3535 1404]
# y label [2, 4, 2, 2, 8]
# 2.0
# nearest index for  193 : [2535 2130  243 4628 1881]
# y label [2, 3, 6, 3, 4]
# 3.0
# nearest index for  194 : [ 951 4703 1220 1126 4429]
# y label [4, 2, 6, 6, 4]
# 4.0
# nearest index for  195 : [2116 4628   54 2650 3226]
# y label [4, 3, 2, 6, 2]
# 2.0
# nearest index for  196 : [2979 1463 2344 1564 1926]
# y label [8, 0, 8, 8, 0]
# 8.0
# nearest index for  197 : [2176 2391 1432 4056 4765]
# y label [8, 0, 0, 2, 0]
# 0.0
# nearest index for  198 : [4184 2699 2223 4790 4232]
# y label [4, 3, 3, 7, 4]
# 3.0
# nearest index for  199 : [2567 3458 4808 3738  952]
# y label [2, 6, 5, 8, 7]
# 2.0
# nearest index for  200 : [  18 3939 1220 3617  560]
# y label [2, 7, 6, 3, 2]
# 2.0
# nearest index for  201 : [4053  448 3573 3304 3882]
# y label [4, 0, 7, 0, 9]
# 0.0
# nearest index for  202 : [ 554 1323  379 3829 1229]
# y label [8, 8, 8, 8, 8]
# 8.0
# nearest index for  203 : [ 910 2018  263 4007 3581]
# y label [2, 8, 4, 3, 7]
# 2.0
# nearest index for  204 : [2725 4647 3178 4066 4304]
# y label [4, 2, 3, 8, 8]
# 8.0
# nearest index for  205 : [ 403 4808 3046 2106 3759]
# y label [2, 5, 4, 4, 4]
# 4.0
# nearest index for  206 : [2350 2277 2789 3789 1282]
# y label [0, 0, 2, 0, 8]
# 0.0
# nearest index for  207 : [ 933 4521 4211 3418 2133]
# y label [2, 2, 2, 4, 2]
# 2.0
# nearest index for  208 : [1220  383  933  120  254]
# y label [6, 2, 2, 2, 4]
# 2.0
# nearest index for  209 : [2171 4455  252  309 3039]
# y label [0, 2, 8, 8, 8]
# 8.0
# nearest index for  210 : [1563 2875 4224  951 2695]
# y label [6, 2, 4, 4, 4]
# 4.0
# nearest index for  211 : [ 121 1506  909 3967 3236]
# y label [2, 8, 8, 8, 4]
# 8.0
# nearest index for  212 : [3436 4552 2079 2858 3979]
# y label [2, 0, 2, 4, 0]
# 0.0
# nearest index for  213 : [ 558 4254 3784  909 3919]
# y label [2, 7, 4, 8, 4]
# 4.0
# nearest index for  214 : [2979 4226  766 1624 3246]
# y label [8, 8, 8, 4, 0]
# 8.0
# nearest index for  215 : [2349 3163 3277 4418 2509]
# y label [2, 5, 0, 2, 5]
# 2.0
# nearest index for  216 : [1593  866  441 4746 2438]
# y label [0, 0, 8, 0, 8]
# 0.0
# nearest index for  217 : [3677 2635 4953  898 1195]
# y label [9, 8, 1, 7, 0]
# 0.0
# nearest index for  218 : [4645 4601 4355 4697 1527]
# y label [0, 0, 5, 3, 2]
# 0.0
# nearest index for  219 : [3418 2716  933 2106 3164]
# y label [4, 7, 2, 4, 2]
# 2.0
# nearest index for  220 : [4706 4147 2213 3326 2796]
# y label [7, 6, 4, 4, 6]
# 4.0
# nearest index for  221 : [ 336 2594 2252  217 2842]
# y label [4, 3, 6, 5, 4]
# 4.0
# nearest index for  222 : [3623 4191 4453 1759 4298]
# y label [7, 8, 2, 0, 8]
# 8.0
# nearest index for  223 : [2350 2594  710 2116  673]
# y label [0, 3, 6, 4, 2]
# 0.0
# nearest index for  224 : [4288 4827 4491 2966 4304]
# y label [3, 3, 2, 2, 8]
# 2.0
# nearest index for  225 : [1809 4715 3138  411 3768]
# y label [6, 4, 7, 2, 7]
# 7.0
# nearest index for  226 : [ 558 3886 2905 4254 3919]
# y label [2, 1, 4, 7, 4]
# 4.0
# nearest index for  227 : [2543 1686 1283  852 2341]
# y label [2, 8, 2, 5, 0]
# 2.0
# nearest index for  228 : [2858 4082 2441 3979 1625]
# y label [4, 6, 8, 0, 3]
# 0.0
# nearest index for  229 : [4987 4693  951 2695 3739]
# y label [4, 6, 4, 4, 6]
# 4.0
# nearest index for  230 : [4108 2766 3670 2943 4125]
# y label [3, 3, 8, 4, 5]
# 3.0
# nearest index for  231 : [3735  364 2664 2893 2055]
# y label [1, 1, 9, 6, 9]
# 1.0
# nearest index for  232 : [ 963 2116 4733 3193  399]
# y label [2, 4, 5, 2, 4]
# 2.0
# nearest index for  233 : [4108  673 3670 1311 1791]
# y label [3, 2, 8, 4, 4]
# 4.0
# nearest index for  234 : [2172 4477 3607 1130 4834]
# y label [8, 0, 0, 0, 8]
# 0.0
# nearest index for  235 : [2247 1243 3049  456 3869]
# y label [2, 0, 0, 8, 2]
# 0.0
# nearest index for  236 : [  10 1530 3560  910 3883]
# y label [4, 2, 4, 2, 8]
# 2.0
# nearest index for  237 : [3882 3501 1490 1413 4053]
# y label [9, 9, 7, 1, 4]
# 9.0
# nearest index for  238 : [1618 1211 4322 2176 3024]
# y label [5, 0, 0, 8, 0]
# 0.0
# nearest index for  239 : [2509 2674 1674 2926 2227]
# y label [5, 6, 0, 4, 1]
# 0.0
# nearest index for  240 : [  77 1470 1201 1990  670]
# y label [0, 0, 9, 2, 5]
# 0.0
# nearest index for  241 : [1284   69 1166 3230 2221]
# y label [4, 8, 0, 1, 8]
# 8.0
# nearest index for  242 : [3116 3845   69  909 3874]
# y label [4, 2, 8, 8, 8]
# 8.0
# nearest index for  243 : [4477 2156 3607 2166  199]
# y label [0, 0, 0, 8, 0]
# 0.0
# nearest index for  244 : [2247 1243 3829 3259 2610]
# y label [2, 0, 8, 2, 2]
# 2.0
# nearest index for  245 : [1122 1613  856  142 3540]
# y label [2, 6, 4, 3, 4]
# 4.0
# nearest index for  246 : [2605 2106 3739 2465  951]
# y label [6, 4, 6, 4, 4]
# 4.0
# nearest index for  247 : [4477 2156 3607 4298 2483]
# y label [0, 0, 0, 8, 8]
# 0.0
# nearest index for  248 : [1832 4905 4224 1677 1760]
# y label [4, 4, 4, 2, 6]
# 4.0
# nearest index for  249 : [2507  850 2959 1351 3621]
# y label [2, 3, 0, 3, 6]
# 3.0
# nearest index for  250 : [3376 4208 2867 2868 1816]
# y label [3, 6, 2, 2, 0]
# 2.0
# nearest index for  251 : [ 914 1367 4033 4720 4579]
# y label [6, 6, 3, 3, 5]
# 3.0
# nearest index for  252 : [ 299 3412 1991  345  990]
# y label [4, 6, 5, 4, 2]
# 4.0
# nearest index for  253 : [1530 2666 2211 3843 1596]
# y label [2, 8, 7, 3, 6]
# 2.0
# nearest index for  254 : [2831 2764 2573 1521 4789]
# y label [6, 2, 4, 5, 6]
# 6.0
# nearest index for  255 : [ 982 4029 4159  987  898]
# y label [4, 8, 8, 8, 7]
# 8.0
# nearest index for  256 : [1881 2730  420  347 2983]
# y label [4, 5, 4, 6, 2]
# 4.0
# nearest index for  257 : [2003  185 3478  444 2172]
# y label [8, 0, 0, 9, 8]
# 0.0
# nearest index for  258 : [2003 3573 2137  909 4469]
# y label [8, 7, 3, 8, 8]
# 8.0
# nearest index for  259 : [4801  399 4969 2216 1126]
# y label [4, 4, 4, 4, 6]
# 4.0
# nearest index for  260 : [2745 4310 3529 1991  107]
# y label [5, 3, 8, 5, 5]
# 5.0
# nearest index for  261 : [2839 4758 1162 3970 1141]
# y label [4, 8, 8, 4, 8]
# 8.0
# nearest index for  262 : [4106  878 1427 4715 1563]
# y label [4, 3, 3, 4, 6]
# 3.0
# nearest index for  263 : [4493  626 2968 2725 4304]
# y label [2, 0, 6, 4, 8]
# 0.0
# nearest index for  264 : [2213 2859   69 1065 2867]
# y label [4, 0, 8, 2, 2]
# 2.0
# nearest index for  265 : [2096  126 1770 2192  704]
# y label [8, 1, 8, 9, 8]
# 8.0
# nearest index for  266 : [2212 2546 2859 2333 1065]
# y label [8, 2, 0, 8, 2]
# 2.0
# nearest index for  267 : [4297 4426   10 2830 1436]
# y label [4, 2, 4, 4, 6]
# 4.0
# nearest index for  268 : [3627 2859  982 1759  592]
# y label [7, 0, 4, 0, 8]
# 0.0
# nearest index for  269 : [1787 3979 2079 2617 4056]
# y label [2, 0, 2, 0, 2]
# 2.0
# nearest index for  270 : [ 383  254 4398 3759 2993]
# y label [2, 4, 2, 4, 2]
# 2.0
# nearest index for  271 : [1283 3376  383 3703 2796]
# y label [2, 3, 2, 3, 6]
# 2.0
# nearest index for  272 : [2150 1367 4946 3560 1692]
# y label [6, 6, 6, 4, 4]
# 6.0
# nearest index for  273 : [3787 4197  918 3742 3920]
# y label [3, 3, 5, 6, 7]
# 3.0
# nearest index for  274 : [3144 3607 2172 1794 1229]
# y label [8, 0, 8, 8, 8]
# 8.0
# nearest index for  275 : [1027 2154 3376 4568 2993]
# y label [6, 3, 3, 6, 2]
# 3.0
# nearest index for  276 : [4571 3977 1431  475 1049]
# y label [0, 9, 8, 8, 9]
# 8.0
# nearest index for  277 : [1746 2983 2698 3797 3418]
# y label [4, 2, 2, 4, 4]
# 4.0
# nearest index for  278 : [ 337 3739  951 3845 2875]
# y label [5, 6, 4, 2, 2]
# 2.0
# nearest index for  279 : [2684 2946 3249  894 4309]
# y label [6, 0, 5, 5, 6]
# 5.0
# nearest index for  280 : [3623 1284 1235 1973 1404]
# y label [7, 4, 9, 1, 8]
# 1.0
# nearest index for  281 : [ 887  552  372 1038 1746]
# y label [4, 6, 4, 6, 4]
# 4.0
# nearest index for  282 : [2796 3376 2867 2710 2193]
# y label [6, 3, 2, 4, 2]
# 2.0
# nearest index for  283 : [ 105 1853  207 3294 3127]
# y label [1, 8, 3, 8, 9]
# 8.0
# nearest index for  284 : [ 811 2715 3304  448 3438]
# y label [8, 7, 0, 0, 0]
# 0.0
# nearest index for  285 : [1826 4527 1500 4868 1229]
# y label [4, 4, 2, 0, 8]
# 4.0
# nearest index for  286 : [ 359 4579 1201 1730  670]
# y label [5, 5, 9, 6, 5]
# 5.0
# nearest index for  287 : [4540 4096 1439 3039 4617]
# y label [0, 0, 8, 8, 8]
# 8.0
# nearest index for  288 : [  69 3939 2603 3845 2875]
# y label [8, 7, 8, 2, 2]
# 2.0
# nearest index for  289 : [4594 1640 4643 4053 3677]
# y label [8, 4, 9, 4, 9]
# 4.0
# nearest index for  290 : [1141 3043  420 1542 4868]
# y label [8, 3, 4, 2, 0]
# 0.0
# nearest index for  291 : [3847  420 2372 3684   58]
# y label [2, 4, 2, 4, 4]
# 4.0
# nearest index for  292 : [1838  347 2372 2730 2812]
# y label [2, 6, 2, 5, 2]
# 2.0
# nearest index for  293 : [2894 1162 3065 4925 4286]
# y label [2, 8, 8, 0, 4]
# 8.0
# nearest index for  294 : [1161 1535 1271 4193 3960]
# y label [6, 4, 3, 4, 5]
# 4.0
# nearest index for  295 : [2573 4224 1832 1728 2875]
# y label [4, 4, 4, 4, 2]
# 4.0
# nearest index for  296 : [3166 1777  243 1917 3383]
# y label [4, 2, 6, 6, 4]
# 4.0
# nearest index for  297 : [1178 4941  757 3918 3184]
# y label [0, 0, 0, 0, 0]
# 0.0
# nearest index for  298 : [2229 3579  557 1249 4723]
# y label [8, 8, 0, 0, 8]
# 8.0
# nearest index for  299 : [ 420 1838 4550 2983 1881]
# y label [4, 2, 6, 2, 4]
# 2.0
# nearest index for  300 : [3383 4106 4482 4732 1530]
# y label [4, 4, 2, 2, 2]
# 2.0
# nearest index for  301 : [3608 3997  982 1067 2998]
# y label [2, 3, 4, 2, 6]
# 2.0
# nearest index for  302 : [ 337 4695  951 1500 2875]
# y label [5, 4, 4, 2, 2]
# 2.0
# nearest index for  303 : [ 986 3423  420 1553 4755]
# y label [2, 2, 4, 3, 2]
# 2.0
# nearest index for  304 : [1677 4905 2779 1881 2522]
# y label [2, 4, 4, 4, 5]
# 4.0
# nearest index for  305 : [2172  406 2192  676 3039]
# y label [8, 9, 9, 1, 8]
# 8.0
# nearest index for  306 : [1643  420 4577 4066 1264]
# y label [8, 4, 0, 8, 4]
# 4.0
# nearest index for  307 : [ 982 4527  120 2868 3376]
# y label [4, 4, 2, 2, 3]
# 2.0
# nearest index for  308 : [1933 2005 2745 3469 3065]
# y label [6, 1, 5, 8, 8]
# 8.0
# nearest index for  309 : [1838 2812  622 2983 3797]
# y label [2, 2, 4, 2, 4]
# 2.0
# nearest index for  310 : [1323 1229 4320 1166 4861]
# y label [8, 8, 8, 0, 0]
# 8.0
# nearest index for  311 : [2730 3797  452 3944 3684]
# y label [5, 4, 6, 2, 4]
# 4.0
# nearest index for  312 : [ 974 2034 4683  557 1340]
# y label [0, 0, 0, 0, 0]
# 0.0
# nearest index for  313 : [4645 2176 1787 4056 3382]
# y label [0, 8, 2, 2, 0]
# 0.0
# nearest index for  314 : [2982 2066   80 3949 3376]
# y label [3, 0, 3, 5, 3]
# 3.0
# nearest index for  315 : [2017  820 3962 1104 1878]
# y label [5, 2, 0, 3, 0]
# 0.0
# nearest index for  316 : [4755 1120 4224 3235 4491]
# y label [2, 3, 4, 2, 2]
# 2.0
# nearest index for  317 : [ 254  933 1500  130  951]
# y label [4, 2, 2, 4, 4]
# 4.0
# nearest index for  318 : [4108 1777 3524 2943 1917]
# y label [3, 2, 3, 4, 6]
# 3.0
# nearest index for  319 : [ 420 3684  564 3949 4224]
# y label [4, 4, 0, 5, 4]
# 4.0
# nearest index for  320 : [4808 2522 1991  933 3458]
# y label [5, 5, 5, 2, 6]
# 5.0
# nearest index for  321 : [1271 3960 4637 1842 2730]
# y label [3, 5, 6, 6, 5]
# 5.0
# nearest index for  322 : [2112 4426 1596  961 4284]
# y label [6, 2, 6, 6, 6]
# 6.0
# nearest index for  323 : [ 931 4969 2943 3797 4905]
# y label [6, 4, 4, 4, 4]
# 4.0
# nearest index for  324 : [1016 2836    3 2372 2178]
# y label [6, 6, 4, 2, 4]
# 4.0
# nearest index for  325 : [2894 1092  526 4066 4774]
# y label [2, 8, 4, 8, 0]
# 8.0
# nearest index for  326 : [ 420 4224 1500 1092 1728]
# y label [4, 4, 2, 8, 4]
# 4.0
# nearest index for  327 : [2266 2197   42  933 1220]
# y label [5, 3, 2, 2, 6]
# 2.0
# nearest index for  328 : [3948  716 1500  564 3913]
# y label [4, 8, 2, 0, 4]
# 4.0
# nearest index for  329 : [3077 2310 4090  392 3213]
# y label [4, 6, 2, 0, 7]
# 0.0
# nearest index for  330 : [4200 3693 4801 3670 3166]
# y label [1, 2, 4, 8, 4]
# 4.0
# nearest index for  331 : [2953 4134 2690 2086 2882]
# y label [9, 7, 6, 9, 0]
# 9.0
# nearest index for  332 : [3164 2213 4224  592 1500]
# y label [2, 4, 4, 8, 2]
# 2.0
# nearest index for  333 : [4687 3245 3540 1917 1436]
# y label [4, 2, 4, 6, 6]
# 4.0
# nearest index for  334 : [2573 1746 2121 2983  622]
# y label [4, 4, 2, 2, 4]
# 4.0
# nearest index for  335 : [4583 3178 3663 2573 2894]
# y label [2, 3, 2, 4, 2]
# 2.0
# nearest index for  336 : [3873  420 4959 4235 3684]
# y label [6, 4, 6, 6, 4]
# 6.0
# nearest index for  337 : [1797 2797 2483 1711 1999]
# y label [8, 8, 8, 0, 0]
# 8.0
# nearest index for  338 : [4056 2598 2478 2987 3669]
# y label [2, 0, 0, 8, 2]
# 0.0
# nearest index for  339 : [4208  982 4527 4954 1441]
# y label [6, 4, 4, 3, 7]
# 4.0
# nearest index for  340 : [2106 3408  933 3759  383]
# y label [4, 4, 2, 4, 2]
# 4.0
# nearest index for  341 : [ 985 3506 1959 2749  986]
# y label [6, 2, 6, 8, 2]
# 2.0
# nearest index for  342 : [2034 3918  557 1664 1340]
# y label [0, 0, 0, 0, 0]
# 0.0
# nearest index for  343 : [4808 4163 4905  952 2522]
# y label [5, 0, 4, 7, 5]
# 5.0
# nearest index for  344 : [4577 1162 4066 2610 1092]
# y label [0, 8, 8, 2, 8]
# 8.0
# nearest index for  345 : [ 180 3423 2730 1070 1207]
# y label [4, 2, 5, 3, 2]
# 2.0
# nearest index for  346 : [1221 1366 2949 4588 4190]
# y label [4, 4, 0, 2, 6]
# 4.0
# nearest index for  347 : [ 804 2133 4703 4130 1968]
# y label [2, 2, 2, 6, 4]
# 2.0
# nearest index for  348 : [1993 1261 1056 1375 4292]
# y label [5, 8, 8, 8, 8]
# 8.0
# nearest index for  349 : [1284  716 3948 4371 2962]
# y label [4, 8, 4, 9, 0]
# 4.0
# nearest index for  350 : [4618 4770  849  345  865]
# y label [9, 6, 2, 4, 3]
# 2.0
# nearest index for  351 : [2595  420  399 4235 3949]
# y label [2, 4, 4, 6, 5]
# 4.0
# nearest index for  352 : [2166 2192 3665 3882  139]
# y label [8, 9, 0, 9, 8]
# 8.0
# nearest index for  353 : [1965 3586 4897  897  284]
# y label [3, 2, 8, 8, 0]
# 8.0
# nearest index for  354 : [ 933 2796  130 4090 3506]
# y label [2, 6, 4, 2, 2]
# 2.0
# nearest index for  355 : [ 767 2794 2868  827 4989]
# y label [5, 5, 2, 2, 4]
# 2.0
# nearest index for  356 : [2796 3376  403 3759  933]
# y label [6, 3, 2, 4, 2]
# 2.0
# nearest index for  357 : [ 951  337  537 4703 2678]
# y label [4, 5, 7, 2, 2]
# 2.0
# nearest index for  358 : [1092  170 4583 1506 3403]
# y label [8, 8, 2, 8, 6]
# 8.0
# nearest index for  359 : [1413 3063 2526 2325  165]
# y label [1, 0, 9, 8, 0]
# 0.0
# nearest index for  360 : [ 196 4304 2725 4715 1838]
# y label [2, 8, 4, 4, 2]
# 2.0
# nearest index for  361 : [2859  490 3028 4361 3476]
# y label [0, 4, 5, 3, 2]
# 0.0
# nearest index for  362 : [ 971 1720 1261 2003 2031]
# y label [8, 8, 8, 8, 8]
# 8.0
# nearest index for  363 : [ 733 2330 1162 3971 2610]
# y label [0, 0, 8, 0, 2]
# 0.0
# nearest index for  364 : [4592 4683 4527 1065 1707]
# y label [0, 0, 4, 2, 1]
# 0.0
# nearest index for  365 : [1770 1597 4539 4717 4222]
# y label [8, 8, 8, 0, 8]
# 8.0
# nearest index for  366 : [2520 1459  622  835 1018]
# y label [4, 7, 4, 1, 4]
# 4.0
# nearest index for  367 : [3987 4755 1162  526 4647]
# y label [0, 2, 8, 4, 2]
# 2.0
# nearest index for  368 : [4919 3549 3259 1491 4773]
# y label [0, 0, 2, 4, 4]
# 0.0
# nearest index for  369 : [4153  980 2922 4905 3377]
# y label [5, 1, 4, 4, 4]
# 4.0
# nearest index for  370 : [2796  383 3376 4156 1283]
# y label [6, 2, 3, 4, 2]
# 2.0
# nearest index for  371 : [2833  600 1770 3330  987]
# y label [2, 0, 8, 8, 8]
# 8.0
# nearest index for  372 : [2995 3380 3573 1711 4053]
# y label [4, 8, 7, 0, 4]
# 4.0
# nearest index for  373 : [ 909 1166 1284 1404 3246]
# y label [8, 0, 4, 8, 0]
# 0.0
# nearest index for  374 : [2253 3226 2787  196   10]
# y label [4, 2, 4, 2, 4]
# 4.0
# nearest index for  375 : [1273  271 3606  420 4304]
# y label [7, 2, 7, 4, 8]
# 7.0
# nearest index for  376 : [4828  290 3250 2798 2593]
# y label [8, 8, 8, 8, 8]
# 8.0
# nearest index for  377 : [1092  558 1295 1404 1431]
# y label [8, 2, 2, 8, 8]
# 8.0
# nearest index for  378 : [ 420 2372 3178 3970 2983]
# y label [4, 2, 3, 4, 2]
# 2.0
# nearest index for  379 : [3193 2372 2983 3797 1184]
# y label [2, 2, 2, 4, 2]
# 2.0
# nearest index for  380 : [ 420 4583 2725 2812 1838]
# y label [4, 2, 4, 2, 2]
# 2.0
# nearest index for  381 : [ 139  909 1711 4053 1726]
# y label [8, 8, 0, 4, 5]
# 8.0
# nearest index for  382 : [ 317 4573 2349 3251 4601]
# y label [0, 4, 2, 7, 0]
# 0.0
# nearest index for  383 : [ 974  743 3579 2034 2513]
# y label [0, 1, 8, 0, 0]
# 0.0
# nearest index for  384 : [3178 2983 1838 2372  684]
# y label [3, 2, 2, 2, 3]
# 2.0
# nearest index for  385 : [4645 2744 4601 4559  790]
# y label [0, 2, 0, 0, 2]
# 0.0
# nearest index for  386 : [1092 4887  909 2389 1404]
# y label [8, 3, 8, 1, 8]
# 8.0
# nearest index for  387 : [2712 3569 3797 1752 1184]
# y label [4, 2, 4, 2, 2]
# 2.0
# nearest index for  388 : [2993 2540  767  392 3372]
# y label [2, 2, 5, 0, 2]
# 2.0
# nearest index for  389 : [2276 2925  827 3074 2310]
# y label [6, 6, 2, 2, 6]
# 6.0
# nearest index for  390 : [ 906  420 4235 1688 2812]
# y label [0, 4, 6, 8, 2]
# 0.0
# nearest index for  391 : [3259  220 2610 2247  733]
# y label [2, 0, 2, 2, 0]
# 2.0
# nearest index for  392 : [3418  990  933 4211 2133]
# y label [4, 2, 2, 2, 2]
# 2.0
# nearest index for  393 : [1842 2479  291 4479  157]
# y label [6, 6, 8, 5, 5]
# 5.0
# nearest index for  394 : [4007 3768 1521 4224 1563]
# y label [3, 7, 5, 4, 6]
# 3.0
# nearest index for  395 : [2465 2106  692   58 3797]
# y label [4, 4, 6, 4, 4]
# 4.0
# nearest index for  396 : [ 420 2854 1867 4235  830]
# y label [4, 2, 2, 6, 2]
# 2.0
# nearest index for  397 : [1220 3213 4772  705  951]
# y label [6, 7, 3, 4, 4]
# 4.0
# nearest index for  398 : [4774 2894 2156  365 2820]
# y label [0, 2, 0, 8, 8]
# 0.0
# nearest index for  399 : [4221 3634 3263 3931 2162]
# y label [3, 8, 0, 8, 3]
# 3.0
# nearest index for  400 : [4858  219 1171  644 1252]
# y label [1, 9, 9, 1, 3]
# 1.0
# nearest index for  401 : [1282  336 3826 2788 2210]
# y label [8, 4, 6, 5, 4]
# 4.0
# nearest index for  402 : [4750 1158 4935  820 4943]
# y label [4, 4, 0, 2, 4]
# 4.0
# nearest index for  403 : [ 566 4287  811 2172  987]
# y label [8, 8, 8, 8, 8]
# 8.0
# nearest index for  404 : [4053  749 2325 2905 4571]
# y label [4, 9, 8, 4, 0]
# 4.0
# nearest index for  405 : [  10 4217 2124 1596  918]
# y label [4, 6, 6, 6, 5]
# 6.0
# nearest index for  406 : [1533  456 1376 1243 4919]
# y label [2, 8, 0, 0, 0]
# 0.0
# nearest index for  407 : [1264 4715  927 3318 2840]
# y label [4, 4, 0, 0, 9]
# 0.0
# nearest index for  408 : [4540  698 3634 3579 2034]
# y label [0, 0, 8, 8, 0]
# 0.0
# nearest index for  409 : [3328 3889  557 3634 2868]
# y label [3, 2, 0, 8, 2]
# 2.0
# nearest index for  410 : [1284 2859  982 1759 1229]
# y label [4, 0, 4, 0, 8]
# 0.0
# nearest index for  411 : [1278 2918 2172 1439 4489]
# y label [0, 8, 8, 8, 9]
# 8.0
# nearest index for  412 : [2540  658 3372 2922 1025]
# y label [2, 0, 2, 4, 3]
# 2.0
# nearest index for  413 : [1746 4905   58 3684 3944]
# y label [4, 4, 4, 4, 2]
# 4.0
# nearest index for  414 : [2224  408 1361 4736 1467]
# y label [2, 9, 9, 7, 9]
# 9.0
# nearest index for  415 : [1277 4812  139  704 2642]
# y label [9, 8, 8, 8, 0]
# 8.0
# nearest index for  416 : [ 695 2598 3438  441  820]
# y label [0, 0, 0, 8, 2]
# 0.0
# nearest index for  417 : [4393 2745 1053 4014 1006]
# y label [7, 5, 6, 2, 1]
# 1.0
# nearest index for  418 : [1881 4411 4604  197 3684]
# y label [4, 0, 2, 3, 4]
# 4.0
# nearest index for  419 : [3784  558  722 4254  909]
# y label [4, 2, 7, 7, 8]
# 7.0
# nearest index for  420 : [ 781  850 4426 4122 2112]
# y label [6, 3, 2, 2, 6]
# 2.0
# nearest index for  421 : [3408 3031 2716 3759 3377]
# y label [4, 5, 7, 4, 4]
# 4.0
# nearest index for  422 : [ 982   69 4277  558 1759]
# y label [4, 8, 8, 2, 0]
# 8.0
# nearest index for  423 : [4087  918  682 3676 1351]
# y label [3, 5, 6, 6, 3]
# 3.0
# nearest index for  424 : [ 933  403 4090 2796  383]
# y label [2, 2, 2, 6, 2]
# 2.0
# nearest index for  425 : [2003 4226 2160 2344 4274]
# y label [8, 8, 8, 8, 8]
# 8.0
# nearest index for  426 : [1842 3060 1600 2986 1503]
# y label [6, 5, 5, 3, 5]
# 5.0
# nearest index for  427 : [3377 4224 2922 4905 1881]
# y label [4, 4, 4, 4, 4]
# 4.0
# nearest index for  428 : [4491 1525 2966 4182 1577]
# y label [2, 5, 2, 4, 7]
# 2.0
# nearest index for  429 : [3892 2127 3411 1362 1017]
# y label [6, 3, 6, 6, 6]
# 6.0
# nearest index for  430 : [1867 1910   80 2678  121]
# y label [2, 4, 3, 2, 2]
# 2.0
# nearest index for  431 : [3493 2707 3176 4466 1686]
# y label [8, 0, 4, 8, 8]
# 8.0
# nearest index for  432 : [3873 1314 3173 3949 2567]
# y label [6, 8, 5, 5, 2]
# 5.0
# nearest index for  433 : [4770  299  345 2666   26]
# y label [6, 4, 4, 8, 3]
# 4.0
# nearest index for  434 : [1092 1284 4887   69 3874]
# y label [8, 4, 3, 8, 8]
# 8.0
# nearest index for  435 : [2943 1875 4969  552 1491]
# y label [4, 5, 4, 6, 4]
# 4.0
# nearest index for  436 : [ 882 1284 4298 1711 3246]
# y label [3, 4, 8, 0, 0]
# 0.0
# nearest index for  437 : [2842 3245 2116 1268 3193]
# y label [4, 2, 4, 4, 2]
# 4.0
# nearest index for  438 : [1530  334 1596 1436 1367]
# y label [2, 3, 6, 6, 6]
# 6.0
# nearest index for  439 : [4661 4349  804 4144  622]
# y label [1, 3, 2, 6, 4]
# 1.0
# nearest index for  440 : [ 592 2575 1832 4808 3627]
# y label [8, 2, 4, 5, 7]
# 2.0
# nearest index for  441 : [  10  910 4007 2812 2018]
# y label [4, 2, 3, 2, 8]
# 2.0
# nearest index for  442 : [1557 4492 4643 1472 4594]
# y label [4, 1, 9, 9, 8]
# 9.0
# nearest index for  443 : [1711 1141  139 1633 2962]
# y label [0, 8, 8, 9, 0]
# 0.0
# nearest index for  444 : [3587  171 2550 4893 4905]
# y label [4, 2, 2, 5, 4]
# 2.0
# nearest index for  445 : [ 673 1126 4232 4857 3717]
# y label [2, 6, 4, 4, 4]
# 4.0
# nearest index for  446 : [2859 1284 4868 1759 1404]
# y label [0, 4, 0, 0, 8]
# 0.0
# nearest index for  447 : [2460 1787 2808 3918 3979]
# y label [0, 2, 0, 0, 0]
# 0.0
# nearest index for  448 : [2543 3376 1283  957  383]
# y label [2, 3, 2, 2, 2]
# 2.0
# nearest index for  449 : [2867 2034  348 3669  349]
# y label [2, 0, 0, 2, 0]
# 0.0
# nearest index for  450 : [1563 1374 2510 2998 4429]
# y label [6, 6, 6, 6, 4]
# 6.0
# nearest index for  451 : [  31 1156  170 2086 1468]
# y label [9, 5, 8, 9, 8]
# 8.0
# nearest index for  452 : [3953  882 2779 1759 4868]
# y label [7, 3, 4, 0, 0]
# 0.0
# nearest index for  453 : [1686 1065 2543 3579  403]
# y label [8, 2, 2, 8, 2]
# 2.0
# nearest index for  454 : [3984 1897 1253 1714 4527]
# y label [1, 3, 9, 9, 4]
# 9.0
# nearest index for  455 : [2543 2710 1030 4198 3326]
# y label [2, 4, 3, 2, 4]
# 2.0
# nearest index for  456 : [2983 3797 3558  242 2787]
# y label [2, 4, 2, 6, 4]
# 2.0
# nearest index for  457 : [2812 1968  830  347 4106]
# y label [2, 4, 2, 6, 4]
# 2.0
# nearest index for  458 : [ 243 2130 4108 2535 3841]
# y label [6, 3, 3, 2, 6]
# 3.0
# nearest index for  459 : [ 882 2881 3246 2483 1711]
# y label [3, 8, 0, 8, 0]
# 0.0
# nearest index for  460 : [ 521 4015 1762 3670 3524]
# y label [4, 6, 4, 8, 3]
# 4.0
# nearest index for  461 : [ 287 4429 4703  337 2069]
# y label [3, 4, 2, 5, 4]
# 4.0
# nearest index for  462 : [1067 2998 1542 1295 1867]
# y label [2, 6, 2, 2, 2]
# 2.0
# nearest index for  463 : [4905 2266 3684 3506 3949]
# y label [4, 5, 4, 2, 5]
# 4.0
# nearest index for  464 : [2868  982 4113 1004  987]
# y label [2, 4, 2, 4, 8]
# 2.0
# nearest index for  465 : [2213 2091  571 1714 1333]
# y label [4, 2, 6, 9, 4]
# 4.0
# nearest index for  466 : [ 158 1019 3167 4301 1047]
# y label [4, 7, 5, 4, 6]
# 4.0
# nearest index for  467 : [2868 4540 2867 3579 4617]
# y label [2, 0, 2, 8, 8]
# 2.0
# nearest index for  468 : [4294 3632  337  703 2521]
# y label [3, 5, 5, 9, 3]
# 3.0
# nearest index for  469 : [1926  933  216 1851  303]
# y label [0, 2, 8, 4, 2]
# 2.0
# nearest index for  470 : [3480   10 2372 3528 2116]
# y label [2, 4, 2, 6, 4]
# 2.0
# nearest index for  471 : [2553 1366  272 2742 1471]
# y label [7, 4, 4, 2, 4]
# 4.0
# nearest index for  472 : [ 328 4338 1166 1763 2330]
# y label [8, 0, 0, 8, 0]
# 0.0
# nearest index for  473 : [2415 4723 1404 2310 1500]
# y label [4, 8, 8, 6, 2]
# 8.0
# nearest index for  474 : [4350 3448 2378 1523 4817]
# y label [3, 5, 2, 2, 5]
# 2.0
# nearest index for  475 : [2922 1318 4864 1910  728]
# y label [4, 6, 4, 4, 6]
# 4.0
# nearest index for  476 : [4224 3164 3418 1220 3213]
# y label [4, 2, 4, 6, 7]
# 4.0
# nearest index for  477 : [ 983  126  704 2156  407]
# y label [0, 1, 8, 0, 0]
# 0.0
# nearest index for  478 : [4703 1018 1038  622 3739]
# y label [2, 4, 6, 4, 6]
# 4.0
# nearest index for  479 : [ 558 3116 2069 4703 1826]
# y label [2, 4, 4, 2, 4]
# 4.0
# nearest index for  480 : [ 901 4159 4935 4540 4953]
# y label [8, 8, 0, 0, 1]
# 0.0
# nearest index for  481 : [3193 2836 3797 2372 2812]
# y label [2, 6, 4, 2, 2]
# 2.0
# nearest index for  482 : [2859   69  600  199 1431]
# y label [0, 8, 0, 0, 8]
# 0.0
# nearest index for  483 : [2943 4905 3377  673 3949]
# y label [4, 4, 4, 2, 5]
# 4.0
# nearest index for  484 : [ 820 3554  571 4242  762]
# y label [2, 6, 6, 2, 5]
# 2.0
# nearest index for  485 : [3874 1092 3063 1431 1726]
# y label [8, 8, 0, 8, 5]
# 8.0
# nearest index for  486 : [1185 3677  753 4215 2635]
# y label [0, 9, 1, 9, 8]
# 9.0
# nearest index for  487 : [ 420 1867 2989 1264 4715]
# y label [4, 2, 6, 4, 4]
# 4.0
# nearest index for  488 : [ 974 4540 3039 4466 1759]
# y label [0, 0, 8, 8, 0]
# 0.0
# nearest index for  489 : [ 557 1009 2333 1664  456]
# y label [0, 2, 8, 0, 8]
# 0.0
# nearest index for  490 : [3469  716  564  452 1881]
# y label [8, 8, 0, 6, 4]
# 8.0
# nearest index for  491 : [ 749 2325 3488 1821 2721]
# y label [9, 8, 2, 8, 8]
# 8.0
# nearest index for  492 : [1431  982 4303  554   69]
# y label [8, 4, 8, 8, 8]
# 8.0
# nearest index for  493 : [2830 3678 1917 1559 1777]
# y label [4, 1, 6, 1, 2]
# 1.0
# nearest index for  494 : [4758 1162 4233   62 1141]
# y label [8, 8, 8, 8, 8]
# 8.0
# nearest index for  495 : [1853 4082 2014 2858 4892]
# y label [8, 6, 0, 4, 8]
# 8.0
# nearest index for  496 : [4283  529 3970  170 4633]
# y label [8, 6, 4, 8, 2]
# 8.0
# nearest index for  497 : [4398  765  349  153 3254]
# y label [2, 0, 0, 4, 2]
# 0.0
# nearest index for  498 : [4224 2875  933  951 3213]
# y label [4, 2, 2, 4, 7]
# 2.0
# nearest index for  499 : [3979 3382 4645 1787 2441]
# y label [0, 0, 0, 2, 8]
# 0.0
# Got 139 / 500 correct => accuracy: 0.278000

# %% [markdown]
# You should expect to see a slightly better performance than with `k = 1`.

# %%
# Now lets speed up distance matrix computation by using partial vectorization
# with one loop. Implement the function compute_distances_one_loop and run the
# code below:
dists_one = classifier.compute_distances_one_loop(X_test)

# To ensure that our vectorized implementation is correct, we make sure that it
# agrees with the naive implementation. There are many ways to decide whether
# two matrices are similar; one of the simplest is the Frobenius norm. In case
# you haven't seen it before, the Frobenius norm of two matrices is the square
# root of the squared sum of differences of all elements; in other words, reshape
# the matrices into vectors and compute the Euclidean distance between them.
difference = np.linalg.norm(dists - dists_one, ord='fro')
print('Difference was: %f' % (difference, ))
if difference < 0.001:
    print('Good! The distance matrices are the same')
else:
    print('Uh-oh! The distance matrices are different')
# Out:
# Difference was: 0.000000
# Good! The distance matrices are the same

# %%
# Now implement the fully vectorized version inside compute_distances_no_loops
# and run the code
dists_two = classifier.compute_distances_no_loops(X_test)

# check that the distance matrix agrees with the one we computed before:
difference = np.linalg.norm(dists - dists_two, ord='fro')
print('Difference was: %f' % (difference, ))
if difference < 0.001:
    print('Good! The distance matrices are the same')
else:
    print('Uh-oh! The distance matrices are different')
# Out:
# (5000, 3072) (500, 3072) (5000,) (500,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-7a25cb0499b9> in <module>()
#       1 # Now implement the fully vectorized version inside compute_distances_no_loops
#       2 # and run the code
# ----> 3 dists_two = classifier.compute_distances_no_loops(X_test)
#       4
#       5 # check that the distance matrix agrees with the one we computed before:
#
# /Users/zhaowenhao/MachineLearning/cs231n_2017/cs231n/assignment1/cs231n/classifiers/k_nearest_neighbor.py in compute_distances_no_loops(self, X)
#     125     #########################################################################
#     126     print(self.X_train.shape, X.shape, np.sum(self.X_train ** 2, axis = 1).shape, np.sum(X ** 2, axis=1).shape)
# --> 127     dists = np.sqrt(np.sum(self.X_train ** 2, axis = 1) + np.sum(X ** 2, axis=1) - 2 * np.dot(X, self.X_train.T))
#     128     #########################################################################
#     129     #                         END OF YOUR CODE                              #
#
# ValueError: operands could not be broadcast together with shapes (5000,) (500,)

# %%
# Let's compare how fast the implementations are
def time_function(f, *args):
    """
    Call a function f with args and return the time (in seconds) that it took to execute.
    """
    import time
    tic = time.time()
    f(*args)
    toc = time.time()
    return toc - tic

two_loop_time = time_function(classifier.compute_distances_two_loops, X_test)
print('Two loop version took %f seconds' % two_loop_time)

one_loop_time = time_function(classifier.compute_distances_one_loop, X_test)
print('One loop version took %f seconds' % one_loop_time)

no_loop_time = time_function(classifier.compute_distances_no_loops, X_test)
print('No loop version took %f seconds' % no_loop_time)

# you should see significantly faster performance with the fully vectorized implementation

# %% [markdown]
# ### Cross-validation
#
# We have implemented the k-Nearest Neighbor classifier but we set the value k = 5 arbitrarily. We will now determine the best value of this hyperparameter with cross-validation.

# %%
num_folds = 5
k_choices = [1, 3, 5, 8, 10, 12, 15, 20, 50, 100]

X_train_folds = []
y_train_folds = []
################################################################################
# TODO:                                                                        #
# Split up the training data into folds. After splitting, X_train_folds and    #
# y_train_folds should each be lists of length num_folds, where                #
# y_train_folds[i] is the label vector for the points in X_train_folds[i].     #
# Hint: Look up the numpy array_split function.                                #
################################################################################
pass
################################################################################
#                                 END OF YOUR CODE                             #
################################################################################

# A dictionary holding the accuracies for different values of k that we find
# when running cross-validation. After running cross-validation,
# k_to_accuracies[k] should be a list of length num_folds giving the different
# accuracy values that we found when using that value of k.
k_to_accuracies = {}


################################################################################
# TODO:                                                                        #
# Perform k-fold cross validation to find the best value of k. For each        #
# possible value of k, run the k-nearest-neighbor algorithm num_folds times,   #
# where in each case you use all but one of the folds as training data and the #
# last fold as a validation set. Store the accuracies for all fold and all     #
# values of k in the k_to_accuracies dictionary.                               #
################################################################################
pass
################################################################################
#                                 END OF YOUR CODE                             #
################################################################################

# Print out the computed accuracies
for k in sorted(k_to_accuracies):
    for accuracy in k_to_accuracies[k]:
        print('k = %d, accuracy = %f' % (k, accuracy))

# %%
# plot the raw observations
for k in k_choices:
    accuracies = k_to_accuracies[k]
    plt.scatter([k] * len(accuracies), accuracies)

# plot the trend line with error bars that correspond to standard deviation
accuracies_mean = np.array([np.mean(v) for k,v in sorted(k_to_accuracies.items())])
accuracies_std = np.array([np.std(v) for k,v in sorted(k_to_accuracies.items())])
plt.errorbar(k_choices, accuracies_mean, yerr=accuracies_std)
plt.title('Cross-validation on k')
plt.xlabel('k')
plt.ylabel('Cross-validation accuracy')
plt.show()

# %%
# Based on the cross-validation results above, choose the best value for k,   
# retrain the classifier using all the training data, and test it on the test
# data. You should be able to get above 28% accuracy on the test data.
best_k = 1

classifier = KNearestNeighbor()
classifier.train(X_train, y_train)
y_test_pred = classifier.predict(X_test, k=best_k)

# Compute and display the accuracy
num_correct = np.sum(y_test_pred == y_test)
accuracy = float(num_correct) / num_test
print('Got %d / %d correct => accuracy: %f' % (num_correct, num_test, accuracy))
